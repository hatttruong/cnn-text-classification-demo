# %% [markdown]
# # Preprocessing
# 1. Remove stop word
# 2. Create dictionary - order is not important --> save file
# 3. Calculate tf-idf for each document --> filter top 400 words
# 4. Replace word by index (of dictionary) - KEEP order
# 5. Create a array of sequences - each sequence is a document --> save file

# %%
import os
import pandas as pd
from nltk import word_tokenize
import time
import nltk
import itertools
import operator
import codecs
from sklearn.feature_extraction.text import TfidfVectorizer
import heapq
import numpy as np
import re
import threading

# %%
def clean_str(string):
    """
    Remove ending character such as .,?;!:
    """
    endings = ['.', '?', ',', '!', ':', ';', '`']
    while len(string) > 0 and string[-1] in endings:
        string = string[:-1]
    
    return string.strip().lower()

# %%
def is_string(string):
    return not (re.match('(\d{1,})', string)
                or re.match('(\d{1,},\d{1,})', string) 
                or re.match('(\d{1,}/\d{1,})', string) 
                or re.match('(\d{1,}.\d{1,})', string))

# %% [markdown]
# ### Load data - split sentences to words and lowercase

# %%
df = pd.read_csv('data/1_data.csv', encoding='utf-8')

# %%
# split sentences to word
start_time = time.time()
df['tokens'] = df['content'].apply(lambda x: word_tokenize(x))
print('Finish spliting sentences into words: %f s' % (time.time() - start_time))
# Out:
# Finish spliting sentences into words: 123.785000 s

# %%
df.head()
# Out:
#                                              content     label  \
# 0  Nhà_vua và Hoàng_hậu Nhật_Bản thăm Cố_đô Huế Đ...  the-gioi
# 1  Chiếc tuần_dương_hạm ngầm xấu_số của hải_quân ...  the-gioi
# 2  Máy_bay chở gia_đình Bin_Laden rơi vì hạ_cánh ...  the-gioi
# 3  Putin gửi lời chúc tới Trump không nhắc đến Ob...  the-gioi
# 4  Trump không đưa Nga vào danh_sách ưu_tiên của ...  the-gioi
#
#                                               tokens
# 0  [Nhà_vua, và, Hoàng_hậu, Nhật_Bản, thăm, Cố_đô...
# 1  [Chiếc, tuần_dương_hạm, ngầm, xấu_số, của, hải...
# 2  [Máy_bay, chở, gia_đình, Bin_Laden, rơi, vì, h...
# 3  [Putin, gửi, lời, chúc, tới, Trump, không, nhắ...
# 4  [Trump, không, đưa, Nga, vào, danh_sách, ưu_ti...

# %%
# Remove single-character tokens (mostly punctuation)
# Remove numbers
# convert all words into lowercase
start_time = time.time()
df['tokens'] = df['tokens'].apply(lambda x: [clean_str(word) for word in x if len(word) > 1 and is_string(word)])

# The last word is often author of document, so we remove it
df['tokens'] = df['tokens'].apply(lambda x: x[:-1])

print('Finish cleaning data: %f s' % (time.time() - start_time))
df.head()
# Out:
# Finish cleaning data: 193.131000 s
#                                              content     label  \
# 0  Nhà_vua và Hoàng_hậu Nhật_Bản thăm Cố_đô Huế Đ...  the-gioi
# 1  Chiếc tuần_dương_hạm ngầm xấu_số của hải_quân ...  the-gioi
# 2  Máy_bay chở gia_đình Bin_Laden rơi vì hạ_cánh ...  the-gioi
# 3  Putin gửi lời chúc tới Trump không nhắc đến Ob...  the-gioi
# 4  Trump không đưa Nga vào danh_sách ưu_tiên của ...  the-gioi
#
#                                               tokens
# 0  [nhà_vua, và, hoàng_hậu, nhật_bản, thăm, cố_đô...
# 1  [chiếc, tuần_dương_hạm, ngầm, xấu_số, của, hải...
# 2  [máy_bay, chở, gia_đình, bin_laden, rơi, vì, h...
# 3  [putin, gửi, lời, chúc, tới, trump, không, nhắ...
# 4  [trump, không, đưa, nga, vào, danh_sách, ưu_ti...

# %%
df['content'] = df['tokens'].apply(lambda x: ' '.join(x))
df.drop('tokens', axis=1, inplace=True)
df.to_csv(os.path.join('data', '2_cleaned_data.csv'), index=False, encoding='utf-8')

# %% [markdown]
# ### Step 1: Remove stopword

# %%
df = pd.read_csv(os.path.join('data', '2_cleaned_data.csv'), encoding='utf-8')
df['content'] = df['content'].apply(lambda x: x.split(' '))
df.head()
# Out:
#                                              content     label
# 0  [nhà_vua, và, hoàng_hậu, nhật_bản, thăm, cố_đô...  the-gioi
# 1  [chiếc, tuần_dương_hạm, ngầm, xấu_số, của, hải...  the-gioi
# 2  [máy_bay, chở, gia_đình, bin_laden, rơi, vì, h...  the-gioi
# 3  [putin, gửi, lời, chúc, tới, trump, không, nhắ...  the-gioi
# 4  [trump, không, đưa, nga, vào, danh_sách, ưu_ti...  the-gioi

# %%
stopwords = []
with codecs.open(os.path.join('data', 'vietnamese-stopwords-dash.txt'), 'r', encoding='utf-8') as f:
    stopwords = f.readlines()

# you may also want to remove whitespace characters like `\n` at the end of each line
stopwords = [x.strip() for x in stopwords]

# %%
print(stopwords[1596])
print(len(df['content'][0]))
# Out:
# và
# 165

# %%
start_time = time.time()
df['content'] = df['content'].apply(lambda x: [word for word in x if word not in stopwords])
print('Finish removing stopwords: %f s' % (time.time() - start_time))
print(len(df['content'][0]))
df.head()
# Out:
# Finish removing stopwords: 700.040000 s
# 106
#                                              content     label
# 0  [nhà_vua, hoàng_hậu, nhật_bản, thăm, cố_đô, hu...  the-gioi
# 1  [tuần_dương_hạm, ngầm, xấu_số, hải_quân, pháp,...  the-gioi
# 2  [máy_bay, chở, gia_đình, bin_laden, rơi, hạ_cá...  the-gioi
# 3  [putin, gửi, chúc, trump, nhắc, obama, thông_đ...  the-gioi
# 4  [trump, nga, danh_sách, ưu_tiên, lầu_năm_góc, ...  the-gioi

# %%
# replace content with new text (remove stopword)
df['content'] = df['content'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#                                              content     label
# 0  nhà_vua hoàng_hậu nhật_bản thăm cố_đô huế đông...  the-gioi
# 1  tuần_dương_hạm ngầm xấu_số hải_quân pháp tàu_n...  the-gioi
# 2  máy_bay chở gia_đình bin_laden rơi hạ_cánh tốc...  the-gioi
# 3  putin gửi chúc trump nhắc obama thông_điệp tổn...  the-gioi
# 4  trump nga danh_sách ưu_tiên lầu_năm_góc danh_s...  the-gioi

# %%
df.to_csv(os.path.join('data', '3_removed_stopwords_data.csv'), index=False, encoding='utf-8')

# %% [markdown]
# ### Step 1b: add index into document, then split into seperate file to prevent the lack of memory

# %%
df = pd.read_csv(os.path.join('data', '3_removed_stopwords_data.csv'), encoding='utf-8')
df['doc_id'] = range(1, len(df) + 1)
df.head()
# Out:
#                                              content     label  doc_id
# 0  nhà_vua hoàng_hậu nhật_bản thăm cố_đô huế đông...  the-gioi       1
# 1  tuần_dương_hạm ngầm xấu_số hải_quân pháp tàu_n...  the-gioi       2
# 2  máy_bay chở gia_đình bin_laden rơi hạ_cánh tốc...  the-gioi       3
# 3  putin gửi chúc trump nhắc obama thông_điệp tổn...  the-gioi       4
# 4  trump nga danh_sách ưu_tiên lầu_năm_góc danh_s...  the-gioi       5

# %%
df.to_csv(os.path.join('data', '4_index_data.csv'), 
          columns=['doc_id', 'content', 'label'], 
          index=False, encoding='utf-8')

# %%
for topic in df.label.unique():
    df_filter = df[df.label == topic]
    file_name = '4_index_data.%s.csv' % topic
    df_filter.to_csv(os.path.join('data', file_name),
                     columns=['doc_id', 'content', 'label'], 
                     index=False, encoding='utf-8')

# %% [markdown]
# ### Step 2. Calculate tf-idf for each document

# %%
df = pd.read_csv(os.path.join('data', '4_index_data.csv'), encoding='utf-8')
df.head()
# Out:
#    doc_id                                            content     label
# 0       1  nhà_vua hoàng_hậu nhật_bản thăm cố_đô huế đông...  the-gioi
# 1       2  tuần_dương_hạm ngầm xấu_số hải_quân pháp tàu_n...  the-gioi
# 2       3  máy_bay chở gia_đình bin_laden rơi hạ_cánh tốc...  the-gioi
# 3       4  putin gửi chúc trump nhắc obama thông_điệp tổn...  the-gioi
# 4       5  trump nga danh_sách ưu_tiên lầu_năm_góc danh_s...  the-gioi

# %%
start_time = time.time()

corpus = df['content']
vectorizer = TfidfVectorizer(min_df=1)
X = vectorizer.fit_transform(corpus)
words = vectorizer.get_feature_names()

print('Finish calculating tfidf: %f s' % (time.time() - start_time))
# Out:
# Finish calculating tfidf: 13.785000 s

# %%
topics = df['label'].unique()
topics
# Out:
# array([u'the-gioi', u'khoa-hoc', u'du-lich', u'giao-duc', u'the-thao',
#        u'thoi-su', u'phap-luat', u'so-hoa', u'oto-xe-may', u'giai-tri',
#        u'kinh-doanh'], dtype=object)

# %% [markdown]
# ### Step 3. Create dictionary - save file

# %%
sorted_words = sorted(words)
word_to_index = dict([(w, i) for i, w in enumerate(sorted_words)])

with open(os.path.join('data', 'dic_words.txt'), 'w') as f:
    for i, w in enumerate(sorted_words):
        f.write('%s,%s\n' % (w.encode('utf-8'), i))

# %% [markdown]
# ### Step 4. Get top N words - Replace word by index (of dictionary) - KEEP order - then save file

# %%
# ref: http://stackoverflow.com/questions/10337533/a-fast-way-to-find-the-largest-n-elements-in-an-numpy-array
# but I see that numpy works better than bottleneck
start_time = time.time()
bn.argpartition(-X[0,:].toarray()[0], 400)[:400]
print('Total time: %fs' % (time.time() - start_time))
# Out:
# Total time: 0.007000s

# %%
start_time = time.time()
top_index_freq_words = np.argpartition(-X[42987,:].toarray()[0], 400)[:400]
top_index_freq_words
df_top_word = list(operator.itemgetter(*top_index_freq_words)(words))
df_words = df.loc[42987, 'content'].split(' ')
index_of_top_words = []
for word in df_words:
    if word in df_top_word:
        index_of_top_words.append(str(word_to_index[word]))
with open('test.txt', 'w') as f:
    f.write(' '.join(index_of_top_words))

# %%
class TextThread (threading.Thread):
    def __init__(self, thread_id, name, nb_top_words, idx_from, idx_to):
        threading.Thread.__init__(self)
        self.threadID = thread_id
        self.name = name
        self.nb_top_words = nb_top_words
        self.idx_from = idx_from
        self.idx_to = idx_to
    def run(self):
        print("Starting %s - from %d to %d\n" % (self.name, self.idx_from, self.idx_to))        
        get_top_n_words(self.name, self.nb_top_words, self.idx_from, self.idx_to)

# %%
def get_top_n_words(thread_name, nb_top_words, idx_from, idx_to):
    start_time = time.time()
    for i in range(idx_from, idx_to):
        doc_id = df.doc_id[i]
        top_index_freq_words = np.argpartition(-X[doc_id - 1,:].toarray()[0], nb_top_words)[:nb_top_words]
        df.at[i, 'top_words'] = list(operator.itemgetter(*top_index_freq_words)(words))
        print('%s - document %d' % (thread_name, doc_id))
        
    print('Total time for %s: %fs\n' % (thread_name, time.time() - start_time))

# %%
# nb_top_words = 400

# df = pd.read_csv(os.path.join('data', '4_index_data.du-lich.csv'), encoding='utf-8')
# df['top_words'] = None
# start_time = time.time()

# # Create 100 docs per thread
# doc_per_thread = 100
# for i in range(0, len(df), doc_per_thread):
#     # define idx_to
#     if i + doc_per_thread > len(df) - 1:
#         idx_to = len(df) - 1
#     else:
#         idx_to = i + doc_per_thread
    
#     get_top_n_words('thread_name', nb_top_words, i, idx_to)
#     break

# %%
# if word in content belong to top_words, replace it by index of word (in dictionary), otherwise, remove it
def replace_content_by_index():
    start_time = time.time()
    df['content'] = df['content'].apply(lambda x: x.split(' '))
    print('Splitting content into words in %fs\n' % (time.time() - start_time))
    
    start_time = time.time()
    for i in range(0, len(df)):
        if len(df.loc[i, 'top_words']) == 0:
            print('WARN: there is no topwords for doc %d' % i)
            continue

        index_of_top_words = []
        for word in df.loc[i, 'content']:
            if word in df.loc[i, 'top_words']:
                index_of_top_words.append(str(word_to_index[word]))

        df.loc[i, 'content'] = ' '.join(index_of_top_words)

    print('Done replace_content_by_index in %fs\n' % (time.time() - start_time))

# %%
nb_top_words = 400
doc_per_thread = 1000
# for each topic, read corresponding file
del df
for topic in topics:
    df = pd.read_csv(os.path.join('data', ('4_index_data.%s.csv' % topic)), encoding='utf-8')
    df['top_words'] = None

    start_time = time.time()
    threads = []

    # Create 1000 docs per thread
    for i in range(0, len(df), doc_per_thread):
        # define idx_to
        if i + doc_per_thread > len(df) - 1:
            idx_to = len(df)
        else:
            idx_to = i + doc_per_thread
        
        thread = TextThread(i + 1, 'thread-%d' % (i + 1), nb_top_words, i, idx_to)
        threads.append(thread)
        thread.start()
        
    # Wait for all threads to complete
    for t in threads:
        t.join()

    # replace content by index of top freq words
    replace_content_by_index()
    
    # save result to file
    df.to_csv(os.path.join('data', 'matrix_data.%s.csv' % (topic)), 
              columns=['doc_id', 'content', 'label'],
              index=False, encoding='utf-8')
    print("TOTAL TIME FOR TOPIC '%s': %fs\n" % (topic, time.time() - start_time))
# Out:
# Starting thread-1 - from 0 to 1000
#
# Starting thread-1001 - from 1000 to 2000
# Starting thread-2001 - from 2000 to 3000
#
#
# Starting thread-3001 - from 3000 to 4000
# thread-1001 - document 1001
#
# Starting thread-4001 - from 4000 to 4479
# thread-1 - document 1thread-2001 - document 2001thread-3001 - document 3001thread-1001 - document 1002
#
#
#
#
# thread-4001 - document 4001  thread-3001 - document 3002thread-1001 - document 1003
# thread-1 - document 2thread-2001 - document 2002
#
#
#
# thread-3001 - document 3003thread-1001 - document 1004thread-4001 - document 4002thread-1 - document 3thread-2001 - document 2003
#
#
#
#
# thread-3001 - document 3004thread-1001 - document 1005thread-4001 - document 4003thread-1 - document 4thread-2001 - document 2004
#
#
#
#
# thread-3001 - document 3005thread-1001 - document 1006thread-4001 - document 4004thread-1 - document 5thread-2001 - document 2005
#
#
#
#
# thread-3001 - document 3006thread-1001 - document 1007thread-4001 - document 4005thread-1 - document 6
#
#
#
# thread-2001 - document 2006thread-3001 - document 3007thread-1001 - document 1008thread-4001 - document 4006thread-1 - document 7
#
#
#
#
#  thread-3001 - document 3008thread-1001 - document 1009thread-4001 - document 4007thread-1 - document 8thread-2001 - document 2007
#
#
#
#
#  thread-1001 - document 1010thread-4001 - document 4008thread-1 - document 9thread-2001 - document 2008thread-3001 - document 3009
#
#
#
#
#  thread-4001 - document 4009thread-1 - document 10thread-2001 - document 2009thread-3001 - document 3010thread-1001 - document 1011
#
#
#
#
# thread-4001 - document 4010thread-1 - document 11thread-2001 - document 2010thread-3001 - document 3011thread-1001 - document 1012
#
#
#
#
# thread-4001 - document 4011thread-1 - document 12thread-2001 - document 2011thread-3001 - document 3012thread-1001 - document 1013
#
#
#
# thread-4001 - document 4012
# thread-2001 - document 2012thread-3001 - document 3013thread-1001 - document 1014
# thread-1 - document 13
#
#
# thread-4001 - document 4013
# thread-2001 - document 2013thread-3001 - document 3014thread-1001 - document 1015
# thread-1 - document 14
#
#
# thread-4001 - document 4014
# thread-2001 - document 2014thread-3001 - document 3015thread-1001 - document 1016
# thread-1 - document 15
#
#
# thread-4001 - document 4015
# thread-2001 - document 2015thread-3001 - document 3016thread-1001 - document 1017
# thread-1 - document 16
#
#
# thread-4001 - document 4016
# thread-2001 - document 2016thread-3001 - document 3017thread-1001 - document 1018
# thread-1 - document 17
#
#
# thread-4001 - document 4017
# thread-2001 - document 2017thread-3001 - document 3018
#
#
# thread-1001 - document 1019thread-4001 - document 4018thread-1 - document 18thread-2001 - document 2018thread-3001 - document 3019
#
#
#
#
# thread-1001 - document 1020thread-4001 - document 4019thread-1 - document 19thread-2001 - document 2019thread-3001 - document 3020
#
#
#
#
# thread-1001 - document 1021thread-4001 - document 4020 thread-2001 - document 2020thread-3001 - document 3021
#
# thread-1 - document 20
#
# thread-1001 - document 1022thread-4001 - document 4021
# thread-2001 - document 2021
#
# thread-1 - document 21
# thread-3001 - document 3022thread-1001 - document 1023thread-4001 - document 4022
# thread-2001 - document 2022
#
#
# thread-1 - document 22
# thread-3001 - document 3023 thread-4001 - document 4023
# thread-2001 - document 2023
# thread-1001 - document 1024
# thread-1 - document 23
# thread-3001 - document 3024
#
# thread-2001 - document 2024
# thread-1001 - document 1025thread-4001 - document 4024thread-1 - document 24
# thread-3001 - document 3025
#
#
# thread-2001 - document 2025
#  thread-4001 - document 4025thread-1 - document 25
# thread-3001 - document 3026thread-1001 - document 1026
#
# thread-2001 - document 2026
#
# thread-4001 - document 4026thread-1 - document 26
# thread-3001 - document 3027thread-1001 - document 1027
#
# thread-2001 - document 2027
#
# thread-4001 - document 4027thread-1 - document 27
# thread-3001 - document 3028thread-1001 - document 1028
#
# thread-2001 - document 2028
#
# thread-4001 - document 4028
# thread-3001 - document 3029
# thread-1 - document 28thread-2001 - document 2029
# thread-1001 - document 1029thread-4001 - document 4029
#
# thread-3001 - document 3030
#
#  thread-2001 - document 2030
# thread-1001 - document 1030 thread-1 - document 29
# thread-3001 - document 3031
# thread-4001 - document 4030
# thread-2001 - document 2031
#
# thread-1 - document 30
# thread-3001 - document 3032thread-1001 - document 1031
# thread-2001 - document 2032
#
# thread-4001 - document 4031thread-1 - document 31thread-3001 - document 3033thread-1001 - document 1032
#
#
#
#
# thread-4001 - document 4032thread-1 - document 32thread-2001 - document 2033thread-3001 - document 3034thread-1001 - document 1033
#
#
#
#
# thread-4001 - document 4033thread-1 - document 33thread-2001 - document 2034 thread-1001 - document 1034
#
#
# thread-3001 - document 3035
# thread-4001 - document 4034thread-1 - document 34thread-2001 - document 2035
# thread-1001 - document 1035
#
#
# thread-3001 - document 3036
# thread-4001 - document 4035 thread-2001 - document 2036
#
# thread-1 - document 35
# thread-3001 - document 3037thread-1001 - document 1036thread-4001 - document 4036
# thread-2001 - document 2037
#
#
# thread-1 - document 36
# thread-3001 - document 3038 thread-4001 - document 4037
# thread-2001 - document 2038
# thread-1001 - document 1037
# thread-1 - document 37
# thread-3001 - document 3039
# thread-4001 - document 4038
#
# thread-1001 - document 1038
# thread-1 - document 38thread-2001 - document 2039thread-3001 - document 3040
# thread-4001 - document 4039
#
#
# thread-1001 - document 1039
# thread-1 - document 39thread-2001 - document 2040thread-3001 - document 3041
# thread-4001 - document 4040
#
#
# thread-1001 - document 1040
# thread-1 - document 40thread-2001 - document 2041thread-3001 - document 3042
# thread-4001 - document 4041
#
#
#
# thread-1 - document 41thread-2001 - document 2042thread-3001 - document 3043thread-1001 - document 1041thread-4001 - document 4042
#
#
#
#
# thread-1 - document 42thread-2001 - document 2043thread-3001 - document 3044thread-1001 - document 1042
#
#
#
# thread-4001 - document 4043thread-1 - document 43thread-2001 - document 2044thread-3001 - document 3045
#
#
#
# thread-1001 - document 1043thread-4001 - document 4044thread-1 - document 44 thread-3001 - document 3046
#
#
# thread-2001 - document 2045
# thread-1001 - document 1044thread-4001 - document 4045thread-1 - document 45
#
#
#
# thread-2001 - document 2046thread-3001 - document 3047thread-1001 - document 1045thread-4001 - document 4046thread-1 - document 46
#
#
#
#
# thread-2001 - document 2047thread-3001 - document 3048thread-1001 - document 1046thread-4001 - document 4047thread-1 - document 47
#
#
#
#
# thread-2001 - document 2048thread-3001 - document 3049thread-1001 - document 1047 thread-1 - document 48
#
#
# thread-4001 - document 4048
# thread-2001 - document 2049thread-3001 - document 3050thread-1001 - document 1048
# thread-1 - document 49
#
#
# thread-4001 - document 4049
# thread-2001 - document 2050thread-3001 - document 3051thread-1001 - document 1049
# thread-1 - document 50
#
#
# thread-4001 - document 4050
# thread-2001 - document 2051thread-3001 - document 3052thread-1001 - document 1050
# thread-1 - document 51
#
#
# thread-4001 - document 4051
# thread-2001 - document 2052thread-3001 - document 3053thread-1001 - document 1051
# thread-1 - document 52
#
#
# thread-4001 - document 4052
# thread-2001 - document 2053thread-3001 - document 3054thread-1001 - document 1052
# thread-1 - document 53
#
#
#
# thread-2001 - document 2054thread-3001 - document 3055thread-1001 - document 1053thread-4001 - document 4053
#
#
#
# thread-1 - document 54thread-2001 - document 2055thread-3001 - document 3056thread-1001 - document 1054thread-4001 - document 4054
#
#
#
#
# thread-1 - document 55thread-2001 - document 2056thread-3001 - document 3057thread-1001 - document 1055
#
#
#
# thread-4001 - document 4055 thread-2001 - document 2057thread-3001 - document 3058thread-1001 - document 1056
# thread-1 - document 56
#
#
# thread-4001 - document 4056
# thread-2001 - document 2058thread-3001 - document 3059
# thread-1 - document 57
#
# thread-1001 - document 1057thread-4001 - document 4057
#  thread-3001 - document 3060
#
# thread-1 - document 58thread-2001 - document 2059
# thread-1001 - document 1058thread-4001 - document 4058
#
# thread-3001 - document 3061
#
# thread-1 - document 59thread-2001 - document 2060
# thread-1001 - document 1059thread-4001 - document 4059
#
# thread-3001 - document 3062
#
#  thread-2001 - document 2061
# thread-1001 - document 1060thread-4001 - document 4060thread-1 - document 60
#
#
#
# thread-2001 - document 2062thread-3001 - document 3063thread-1001 - document 1061thread-4001 - document 4061thread-1 - document 61
#
#
#
#
# thread-2001 - document 2063 thread-1001 - document 1062thread-4001 - document 4062thread-1 - document 62
# thread-3001 - document 3064
#
#
# thread-2001 - document 2064
# thread-1001 - document 1063thread-4001 - document 4063thread-1 - document 63
# thread-3001 - document 3065
#
#
# thread-2001 - document 2065
# thread-1001 - document 1064thread-4001 - document 4064thread-1 - document 64
# thread-3001 - document 3066
#
# thread-2001 - document 2066
#
# thread-1 - document 65
# thread-3001 - document 3067thread-1001 - document 1065thread-4001 - document 4065
# thread-2001 - document 2067
#
#
# thread-1 - document 66
# thread-3001 - document 3068thread-1001 - document 1066thread-4001 - document 4066
# thread-2001 - document 2068
#
#
# thread-1 - document 67
#  thread-1001 - document 1067
#  thread-3001 - document 3069
# thread-4001 - document 4067thread-1 - document 68thread-2001 - document 2069
# thread-1001 - document 1068
#
#
# thread-3001 - document 3070
# thread-4001 - document 4068thread-1 - document 69thread-2001 - document 2070
# thread-1001 - document 1069
#
#
# thread-3001 - document 3071
#   thread-2001 - document 2071
# thread-1001 - document 1070thread-4001 - document 4069thread-1 - document 70
# thread-3001 - document 3072
#
#
# thread-2001 - document 2072
# thread-1001 - document 1071thread-4001 - document 4070thread-1 - document 71
# thread-3001 - document 3073
#
#
# thread-2001 - document 2073
# thread-1001 - document 1072 thread-1 - document 72
#
# thread-4001 - document 4071
# thread-2001 - document 2074thread-3001 - document 3074
# thread-1 - document 73
#
# thread-1001 - document 1073thread-4001 - document 4072
# thread-2001 - document 2075thread-3001 - document 3075
#
#
#
# thread-1001 - document 1074thread-4001 - document 4073thread-1 - document 74thread-2001 - document 2076thread-3001 - document 3076
#
#
#
#
# thread-1001 - document 1075thread-4001 - document 4074thread-1 - document 75thread-2001 - document 2077
#
#
#
# thread-3001 - document 3077thread-1001 - document 1076thread-4001 - document 4075thread-1 - document 76thread-2001 - document 2078
#
#
#
#
#  thread-1001 - document 1077thread-4001 - document 4076thread-1 - document 77thread-2001 - document 2079thread-3001 - document 3078
#
#
#
#
# thread-1001 - document 1078thread-4001 - document 4077thread-1 - document 78thread-2001 - document 2080thread-3001 - document 3079
#
#
#
#
#  thread-4001 - document 4078thread-1 - document 79thread-2001 - document 2081thread-3001 - document 3080thread-1001 - document 1079
#
#
#
#
# thread-4001 - document 4079thread-1 - document 80 thread-3001 - document 3081thread-1001 - document 1080
#
# thread-2001 - document 2082
#
# thread-4001 - document 4080thread-1 - document 81
# thread-3001 - document 3082thread-1001 - document 1081
#
#
#
# thread-4001 - document 4081thread-1 - document 82thread-2001 - document 2083thread-3001 - document 3083thread-1001 - document 1082
#
#
#
#
# thread-4001 - document 4082thread-1 - document 83 thread-3001 - document 3084
#
# thread-2001 - document 2084
# thread-1001 - document 1083 thread-1 - document 84
#
# thread-4001 - document 4083
# thread-2001 - document 2085thread-3001 - document 3085thread-1001 - document 1084
# thread-1 - document 85
#
#
# thread-4001 - document 4084
# thread-2001 - document 2086thread-3001 - document 3086thread-1001 - document 1085
# thread-1 - document 86
#
#
# thread-4001 - document 4085
# thread-2001 - document 2087thread-3001 - document 3087thread-1001 - document 1086
# thread-1 - document 87
#
#
# thread-4001 - document 4086
# thread-2001 - document 2088thread-3001 - document 3088thread-1001 - document 1087
# thread-1 - document 88
#
#
# thread-4001 - document 4087
# thread-2001 - document 2089thread-3001 - document 3089
# thread-1 - document 89
#
# thread-1001 - document 1088thread-4001 - document 4088
# thread-2001 - document 2090thread-3001 - document 3090
#
# thread-1 - document 90
#
# thread-1001 - document 1089thread-4001 - document 4089
#  thread-3001 - document 3091
#
# thread-1 - document 91thread-2001 - document 2091
# thread-1001 - document 1090thread-4001 - document 4090
#
# thread-3001 - document 3092
#
# thread-1 - document 92thread-2001 - document 2092
#  thread-4001 - document 4091
#
# thread-3001 - document 3093thread-1001 - document 1091
# thread-1 - document 93thread-2001 - document 2093
#
# thread-4001 - document 4092
#
# thread-3001 - document 3094thread-1001 - document 1092
# thread-1 - document 94thread-2001 - document 2094
#
# thread-4001 - document 4093
#
# thread-3001 - document 3095thread-1001 - document 1093
# thread-1 - document 95thread-2001 - document 2095
#
# thread-4001 - document 4094
#
# thread-3001 - document 3096thread-1001 - document 1094
# thread-1 - document 96thread-2001 - document 2096
#
# thread-4001 - document 4095
#
# thread-3001 - document 3097thread-1001 - document 1095
# thread-1 - document 97
#
#
# thread-2001 - document 2097thread-3001 - document 3098thread-1001 - document 1096thread-4001 - document 4096thread-1 - document 98
#
#
#
#
# thread-2001 - document 2098thread-3001 - document 3099thread-1001 - document 1097thread-4001 - document 4097
#
#
#
# thread-1 - document 99thread-2001 - document 2099 thread-1001 - document 1098thread-4001 - document 4098
#
# thread-3001 - document 3100
#
# thread-1 - document 100thread-2001 - document 2100
# thread-1001 - document 1099thread-4001 - document 4099
#
# thread-3001 - document 3101
#
# thread-1 - document 101thread-2001 - document 2101
# thread-1001 - document 1100thread-4001 - document 4100
#
# thread-3001 - document 3102
#
# thread-1 - document 102thread-2001 - document 2102
# thread-1001 - document 1101thread-4001 - document 4101
#
# thread-3001 - document 3103
#
# thread-1 - document 103thread-2001 - document 2103
# thread-1001 - document 1102
#
# thread-3001 - document 3104
# thread-4001 - document 4102thread-1 - document 104thread-2001 - document 2104
# thread-1001 - document 1103
#
#
# thread-3001 - document 3105
#  thread-1 - document 105thread-2001 - document 2105
# thread-1001 - document 1104thread-4001 - document 4103
#
# thread-3001 - document 3106
#
# thread-1 - document 106thread-2001 - document 2106
# thread-1001 - document 1105thread-4001 - document 4104
#
#
#
#  thread-2001 - document 2107thread-3001 - document 3107thread-1001 - document 1106 thread-1 - document 107
#
#
# thread-4001 - document 4105
# thread-2001 - document 2108thread-3001 - document 3108thread-1001 - document 1107
# thread-1 - document 108
#
#
# thread-4001 - document 4106
# thread-2001 - document 2109thread-3001 - document 3109thread-1001 - document 1108
# thread-1 - document 109
#
#
# thread-4001 - document 4107
#  thread-3001 - document 3110thread-1001 - document 1109
# thread-1 - document 110thread-2001 - document 2110
#
# thread-4001 - document 4108
#
# thread-3001 - document 3111thread-1001 - document 1110
# thread-1 - document 111
#
# thread-4001 - document 4109
# thread-2001 - document 2111thread-3001 - document 3112thread-1001 - document 1111
# thread-1 - document 112
#
#
# thread-4001 - document 4110
# thread-2001 - document 2112thread-3001 - document 3113thread-1001 - document 1112
# thread-1 - document 113
#
#
# thread-4001 - document 4111
# thread-2001 - document 2113thread-3001 - document 3114thread-1001 - document 1113
#
#
#
# thread-4001 - document 4112thread-1 - document 114thread-2001 - document 2114thread-3001 - document 3115
#
#
#
# thread-1001 - document 1114thread-4001 - document 4113thread-1 - document 115
#
#
# thread-2001 - document 2115thread-3001 - document 3116thread-1001 - document 1115thread-4001 - document 4114thread-1 - document 116
#
#
#
#
# thread-2001 - document 2116thread-3001 - document 3117thread-1001 - document 1116thread-4001 - document 4115thread-1 - document 117
#
#
#
#
# thread-2001 - document 2117 thread-1001 - document 1117thread-4001 - document 4116thread-1 - document 118
# thread-3001 - document 3118
#
#
# thread-2001 - document 2118
# thread-1001 - document 1118thread-4001 - document 4117thread-1 - document 119
# thread-3001 - document 3119
#
#
#
# thread-1001 - document 1119thread-4001 - document 4118thread-1 - document 120thread-2001 - document 2119
#
#
#
# thread-3001 - document 3120thread-1001 - document 1120thread-4001 - document 4119thread-1 - document 121thread-2001 - document 2120
#
#
#
# thread-3001 - document 3121thread-1001 - document 1121thread-4001 - document 4120thread-1 - document 122
#
#
#
#
# thread-2001 - document 2121thread-3001 - document 3122thread-1001 - document 1122thread-4001 - document 4121thread-1 - document 123
#
#
#
#
# thread-2001 - document 2122thread-3001 - document 3123thread-1001 - document 1123 thread-1 - document 124
#
#
# thread-4001 - document 4122
#  thread-3001 - document 3124thread-1001 - document 1124
# thread-1 - document 125thread-2001 - document 2123
#
# thread-4001 - document 4123
#
# thread-3001 - document 3125thread-1001 - document 1125
# thread-1 - document 126thread-2001 - document 2124
#
# thread-4001 - document 4124
#
# thread-3001 - document 3126thread-1001 - document 1126
# thread-1 - document 127thread-2001 - document 2125
#
# thread-4001 - document 4125
#
# thread-3001 - document 3127
#  thread-2001 - document 2126
# thread-1001 - document 1127thread-4001 - document 4126thread-1 - document 128
# thread-3001 - document 3128
#
#
#
# thread-1001 - document 1128thread-4001 - document 4127thread-1 - document 129thread-2001 - document 2127thread-3001 - document 3129
#
#
#
#
# thread-1001 - document 1129thread-4001 - document 4128 thread-2001 - document 2128
#
# thread-1 - document 130
# thread-3001 - document 3130thread-1001 - document 1130thread-4001 - document 4129
# thread-2001 - document 2129
#
#
# thread-1 - document 131
# thread-3001 - document 3131thread-1001 - document 1131thread-4001 - document 4130
# thread-2001 - document 2130
#
#
# thread-1 - document 132
# thread-3001 - document 3132thread-1001 - document 1132thread-4001 - document 4131
#
#
#
# thread-1 - document 133thread-2001 - document 2131 thread-1001 - document 1133thread-4001 - document 4132
#
# thread-3001 - document 3133
#
# thread-1 - document 134thread-2001 - document 2132
# thread-1001 - document 1134thread-4001 - document 4133
#
#
#
# thread-1 - document 135thread-2001 - document 2133thread-3001 - document 3134thread-1001 - document 1135thread-4001 - document 4134
#
#
#
#
# thread-1 - document 136thread-2001 - document 2134thread-3001 - document 3135thread-1001 - document 1136thread-4001 - document 4135
#
#
#
#
# thread-1 - document 137thread-2001 - document 2135thread-3001 - document 3136thread-1001 - document 1137thread-4001 - document 4136
#
#
#
#
# thread-1 - document 138thread-2001 - document 2136thread-3001 - document 3137 thread-4001 - document 4137
#
#
# thread-1001 - document 1138
# thread-1 - document 139thread-2001 - document 2137thread-3001 - document 3138
# thread-4001 - document 4138
#
#
# thread-1001 - document 1139
# thread-1 - document 140 thread-3001 - document 3139
# thread-4001 - document 4139
# thread-2001 - document 2138
# thread-1001 - document 1140
# thread-1 - document 141
# thread-3001 - document 3140
# thread-4001 - document 4140
#
# thread-1001 - document 1141
#  thread-2001 - document 2139thread-3001 - document 3141
# thread-4001 - document 4141thread-1 - document 142
#
# thread-1001 - document 1142
#
# thread-2001 - document 2140thread-3001 - document 3142
# thread-4001 - document 4142thread-1 - document 143
#
# thread-1001 - document 1143
#
# thread-2001 - document 2141thread-3001 - document 3143
# thread-4001 - document 4143thread-1 - document 144
#
# thread-1001 - document 1144
#
#  thread-3001 - document 3144
# thread-4001 - document 4144thread-1 - document 145thread-2001 - document 2142
# thread-1001 - document 1145
#
#
#
# thread-4001 - document 4145thread-1 - document 146thread-2001 - document 2143thread-3001 - document 3145thread-1001 - document 1146
#
#
#
#
#  thread-1 - document 147 thread-3001 - document 3146thread-1001 - document 1147thread-4001 - document 4146
# thread-2001 - document 2144
#
#
# thread-1 - document 148
#  thread-1001 - document 1148thread-4001 - document 4147
# thread-2001 - document 2145thread-3001 - document 3147
#
# thread-1 - document 149
#
#  thread-4001 - document 4148
#  thread-3001 - document 3148thread-1001 - document 1149
# thread-1 - document 150thread-2001 - document 2146
#
# thread-4001 - document 4149
#
# thread-3001 - document 3149thread-1001 - document 1150
# thread-1 - document 151thread-2001 - document 2147
#
# thread-4001 - document 4150
#
# thread-3001 - document 3150thread-1001 - document 1151
# thread-1 - document 152thread-2001 - document 2148
#
# thread-4001 - document 4151
#
# thread-3001 - document 3151thread-1001 - document 1152
#  thread-2001 - document 2149
#
# thread-4001 - document 4152thread-1 - document 153
# thread-3001 - document 3152thread-1001 - document 1153
#
# thread-2001 - document 2150
#
# thread-4001 - document 4153thread-1 - document 154
# thread-3001 - document 3153
#
# thread-2001 - document 2151
# thread-1001 - document 1154thread-4001 - document 4154thread-1 - document 155
#
#
#
# thread-2001 - document 2152thread-3001 - document 3154thread-1001 - document 1155thread-4001 - document 4155thread-1 - document 156
#
#
#
#
# thread-2001 - document 2153thread-3001 - document 3155thread-1001 - document 1156thread-4001 - document 4156
#
#
#
# thread-1 - document 157 thread-3001 - document 3156thread-1001 - document 1157thread-4001 - document 4157
# thread-2001 - document 2154
#
#
# thread-1 - document 158
# thread-3001 - document 3157thread-1001 - document 1158
# thread-2001 - document 2155
#
# thread-4001 - document 4158thread-1 - document 159
#  thread-1001 - document 1159
#
# thread-2001 - document 2156thread-3001 - document 3158
# thread-4001 - document 4159thread-1 - document 160
#
#
#
# thread-2001 - document 2157thread-3001 - document 3159thread-1001 - document 1160 thread-1 - document 161
#
#
# thread-4001 - document 4160
# thread-2001 - document 2158thread-3001 - document 3160thread-1001 - document 1161
# thread-1 - document 162
#
#
# thread-4001 - document 4161
# thread-2001 - document 2159thread-3001 - document 3161thread-1001 - document 1162
# thread-1 - document 163
#
#
# thread-4001 - document 4162
# thread-2001 - document 2160thread-3001 - document 3162thread-1001 - document 1163
#
#
#
# thread-4001 - document 4163thread-1 - document 164 thread-3001 - document 3163thread-1001 - document 1164
#
# thread-2001 - document 2161
#
# thread-4001 - document 4164thread-1 - document 165
# thread-3001 - document 3164thread-1001 - document 1165
#
#
#
# thread-4001 - document 4165thread-1 - document 166thread-2001 - document 2162thread-3001 - document 3165thread-1001 - document 1166
#
#
#
#
#   thread-2001 - document 2163thread-3001 - document 3166thread-1001 - document 1167thread-4001 - document 4166thread-1 - document 167
#
#
#
#
# thread-2001 - document 2164  thread-4001 - document 4167thread-1 - document 168
# thread-3001 - document 3167thread-1001 - document 1168
#
# thread-2001 - document 2165
#
# thread-4001 - document 4168thread-1 - document 169
# thread-3001 - document 3168thread-1001 - document 1169
#
# thread-2001 - document 2166
#
#  thread-1 - document 170
#  thread-1001 - document 1170thread-4001 - document 4169
# thread-2001 - document 2167thread-3001 - document 3169
#
# thread-1 - document 171
#
# thread-1001 - document 1171
# thread-2001 - document 2168thread-3001 - document 3170
# thread-4001 - document 4170thread-1 - document 172
#
# thread-1001 - document 1172
#
# thread-2001 - document 2169thread-3001 - document 3171
# thread-4001 - document 4171thread-1 - document 173
#
#
#
# thread-2001 - document 2170thread-3001 - document 3172thread-1001 - document 1173thread-4001 - document 4172thread-1 - document 174
#
#
#
#
#  thread-3001 - document 3173thread-1001 - document 1174thread-4001 - document 4173 thread-2001 - document 2171
#
#
# thread-1 - document 175
# thread-3001 - document 3174thread-1001 - document 1175thread-4001 - document 4174
# thread-2001 - document 2172
#
#
# thread-1 - document 176
# thread-3001 - document 3175 thread-4001 - document 4175
#
# thread-1001 - document 1176
# thread-1 - document 177thread-2001 - document 2173
# thread-4001 - document 4176
#
# thread-3001 - document 3176thread-1001 - document 1177
# thread-1 - document 178thread-2001 - document 2174
#
# thread-4001 - document 4177
#
# thread-3001 - document 3177thread-1001 - document 1178
#  thread-2001 - document 2175
#
# thread-4001 - document 4178thread-1 - document 179
# thread-3001 - document 3178
#
# thread-2001 - document 2176
# thread-1001 - document 1179thread-4001 - document 4179
# thread-3001 - document 3179
#
# thread-1 - document 180thread-2001 - document 2177
#
#
# thread-3001 - document 3180thread-1001 - document 1180thread-4001 - document 4180thread-1 - document 181thread-2001 - document 2178
#
#
#
#
# thread-3001 - document 3181thread-1001 - document 1181thread-4001 - document 4181thread-1 - document 182thread-2001 - document 2179
#
#
#
#
# thread-3001 - document 3182thread-1001 - document 1182thread-4001 - document 4182thread-1 - document 183thread-2001 - document 2180
#
#
#
#
# thread-3001 - document 3183 thread-4001 - document 4183thread-1 - document 184thread-2001 - document 2181
# thread-1001 - document 1183
#
#
# thread-3001 - document 3184
# thread-4001 - document 4184thread-1 - document 185thread-2001 - document 2182
# thread-1001 - document 1184
#
#
# thread-3001 - document 3185
# thread-4001 - document 4185thread-1 - document 186
# thread-1001 - document 1185
#
# thread-2001 - document 2183thread-3001 - document 3186
# thread-4001 - document 4186thread-1 - document 187
#
# thread-1001 - document 1186
#
# thread-2001 - document 2184thread-3001 - document 3187
# thread-4001 - document 4187thread-1 - document 188
#
#
#
# thread-2001 - document 2185thread-3001 - document 3188thread-1001 - document 1187thread-4001 - document 4188
#
#
#
# thread-1 - document 189thread-2001 - document 2186thread-3001 - document 3189 thread-4001 - document 4189
#
#
# thread-1001 - document 1188
# thread-1 - document 190thread-2001 - document 2187thread-3001 - document 3190
# thread-4001 - document 4190
#
#
# thread-1001 - document 1189
# thread-1 - document 191 thread-3001 - document 3191
# thread-4001 - document 4191
# thread-2001 - document 2188
# thread-1001 - document 1190
# thread-1 - document 192
# thread-3001 - document 3192
# thread-4001 - document 4192
# thread-2001 - document 2189
# thread-1001 - document 1191
# thread-1 - document 193
# thread-3001 - document 3193
#
# thread-2001 - document 2190
# thread-1001 - document 1192thread-4001 - document 4193thread-1 - document 194
# thread-3001 - document 3194
#
#
# thread-2001 - document 2191
#  thread-4001 - document 4194thread-1 - document 195
#  thread-1001 - document 1193
#
# thread-2001 - document 2192thread-3001 - document 3195
#  thread-1 - document 196
#
# thread-1001 - document 1194thread-4001 - document 4195
# thread-2001 - document 2193
#
# thread-1 - document 197
# thread-3001 - document 3196thread-1001 - document 1195thread-4001 - document 4196
# thread-2001 - document 2194
#
#
# thread-1 - document 198
#  thread-1001 - document 1196thread-4001 - document 4197
# thread-2001 - document 2195thread-3001 - document 3197
#
# thread-1 - document 199
#
# thread-1001 - document 1197
# thread-2001 - document 2196thread-3001 - document 3198
# thread-4001 - document 4198thread-1 - document 200
#
# thread-1001 - document 1198
#
# thread-2001 - document 2197thread-3001 - document 3199
# thread-4001 - document 4199thread-1 - document 201
#
# thread-1001 - document 1199
#
# thread-2001 - document 2198thread-3001 - document 3200
# thread-4001 - document 4200thread-1 - document 202
#
# thread-1001 - document 1200
#
# thread-2001 - document 2199thread-3001 - document 3201
# thread-4001 - document 4201thread-1 - document 203
#
# thread-1001 - document 1201
#
# thread-2001 - document 2200thread-3001 - document 3202
#  thread-1 - document 204
#
# thread-1001 - document 1202thread-4001 - document 4202
# thread-2001 - document 2201thread-3001 - document 3203
#
# thread-1 - document 205
#
# thread-1001 - document 1203thread-4001 - document 4203
#  thread-3001 - document 3204
#
# thread-1 - document 206thread-2001 - document 2202
# thread-1001 - document 1204thread-4001 - document 4204
#
# thread-3001 - document 3205
#
# thread-1 - document 207
# thread-1001 - document 1205thread-4001 - document 4205
# thread-2001 - document 2203thread-3001 - document 3206
#
# thread-1 - document 208
#
# thread-1001 - document 1206thread-4001 - document 4206
#  thread-3001 - document 3207
#
# thread-1 - document 209thread-2001 - document 2204
# thread-1001 - document 1207thread-4001 - document 4207
#
# thread-3001 - document 3208
#
# thread-1 - document 210thread-2001 - document 2205
# thread-1001 - document 1208thread-4001 - document 4208
#
# thread-3001 - document 3209
#
#  thread-2001 - document 2206
# thread-1001 - document 1209thread-4001 - document 4209thread-1 - document 211
# thread-3001 - document 3210
#
#
#
# thread-1001 - document 1210thread-4001 - document 4210 thread-2001 - document 2207thread-3001 - document 3211
#
# thread-1 - document 212
#
# thread-1001 - document 1211thread-4001 - document 4211
# thread-2001 - document 2208thread-3001 - document 3212
#
# thread-1 - document 213
#
# thread-1001 - document 1212thread-4001 - document 4212
# thread-2001 - document 2209thread-3001 - document 3213
#
# thread-1 - document 214
#
# thread-1001 - document 1213thread-4001 - document 4213
# thread-2001 - document 2210
#
# thread-1 - document 215
# thread-3001 - document 3214thread-1001 - document 1214
#
#
# thread-4001 - document 4214thread-1 - document 216thread-2001 - document 2211 thread-1001 - document 1215
#
#
# thread-3001 - document 3215
# thread-4001 - document 4215thread-1 - document 217
# thread-1001 - document 1216
#
# thread-2001 - document 2212thread-3001 - document 3216
# thread-4001 - document 4216thread-1 - document 218
#
# thread-1001 - document 1217
#
# thread-2001 - document 2213thread-3001 - document 3217
# thread-4001 - document 4217thread-1 - document 219
#
# thread-1001 - document 1218
#
# thread-2001 - document 2214thread-3001 - document 3218
#  thread-1 - document 220
#
# thread-1001 - document 1219thread-4001 - document 4218
# thread-2001 - document 2215
#
# thread-1 - document 221
# thread-3001 - document 3219thread-1001 - document 1220thread-4001 - document 4219
# thread-2001 - document 2216
#
#
# thread-1 - document 222
# thread-3001 - document 3220thread-1001 - document 1221thread-4001 - document 4220
#
#
#
# thread-1 - document 223thread-2001 - document 2217thread-3001 - document 3221 thread-4001 - document 4221
#
#
# thread-1001 - document 1222
# thread-1 - document 224thread-2001 - document 2218thread-3001 - document 3222
# thread-4001 - document 4222
#
#
#
# thread-1 - document 225thread-2001 - document 2219 thread-1001 - document 1223thread-4001 - document 4223
#
# thread-3001 - document 3223
#
# thread-1 - document 226thread-2001 - document 2220
#  thread-4001 - document 4224
#
# thread-3001 - document 3224thread-1001 - document 1224
# thread-1 - document 227
#
# thread-4001 - document 4225
# thread-2001 - document 2221thread-3001 - document 3225thread-1001 - document 1225
# thread-1 - document 228
#
#
# thread-4001 - document 4226
# thread-2001 - document 2222thread-3001 - document 3226thread-1001 - document 1226
# thread-1 - document 229
#
#
# thread-4001 - document 4227
# thread-2001 - document 2223thread-3001 - document 3227
# thread-1 - document 230
#
# thread-1001 - document 1227thread-4001 - document 4228
# thread-2001 - document 2224
#
# thread-1 - document 231
# thread-3001 - document 3228thread-1001 - document 1228thread-4001 - document 4229
# thread-2001 - document 2225
#
#
# thread-1 - document 232
#   thread-4001 - document 4230
#  thread-3001 - document 3229thread-1001 - document 1229
#  thread-2001 - document 2226
#
# thread-4001 - document 4231thread-1 - document 233
# thread-3001 - document 3230thread-1001 - document 1230
#
# thread-2001 - document 2227
#
# thread-4001 - document 4232thread-1 - document 234
#  thread-1001 - document 1231
#
# thread-2001 - document 2228thread-3001 - document 3231
# thread-4001 - document 4233thread-1 - document 235
#
# thread-1001 - document 1232
#
# thread-2001 - document 2229thread-3001 - document 3232
# thread-4001 - document 4234thread-1 - document 236
#
# thread-1001 - document 1233
#
# thread-2001 - document 2230thread-3001 - document 3233
# thread-4001 - document 4235
#
# thread-1001 - document 1234
# thread-1 - document 237thread-2001 - document 2231thread-3001 - document 3234
# thread-4001 - document 4236
#
#
# thread-1001 - document 1235
# thread-1 - document 238thread-2001 - document 2232thread-3001 - document 3235
# thread-4001 - document 4237
#
#
# thread-1001 - document 1236
# thread-1 - document 239thread-2001 - document 2233thread-3001 - document 3236
# thread-4001 - document 4238
#
#
# thread-1001 - document 1237
# thread-1 - document 240thread-2001 - document 2234
#
#
# thread-3001 - document 3237thread-1001 - document 1238thread-4001 - document 4239thread-1 - document 241thread-2001 - document 2235
#
#
#
#
#  thread-1001 - document 1239thread-4001 - document 4240thread-1 - document 242thread-2001 - document 2236thread-3001 - document 3238
#
#
#
#
# thread-1001 - document 1240 thread-1 - document 243
# thread-4001 - document 4241
# thread-2001 - document 2237thread-3001 - document 3239thread-1001 - document 1241
# thread-1 - document 244
#
#
#
# thread-2001 - document 2238 thread-1001 - document 1242thread-4001 - document 4242thread-1 - document 245
# thread-3001 - document 3240
#
#
# thread-2001 - document 2239
# thread-1001 - document 1243 thread-1 - document 246
# thread-3001 - document 3241
# thread-4001 - document 4243
# thread-2001 - document 2240
# thread-1001 - document 1244
# thread-1 - document 247
# thread-3001 - document 3242
#
# thread-2001 - document 2241
# thread-1001 - document 1245thread-4001 - document 4244thread-1 - document 248
# thread-3001 - document 3243
#
#
# thread-2001 - document 2242
#  thread-4001 - document 4245
# thread-3001 - document 3244thread-1001 - document 1246
# thread-1 - document 249thread-2001 - document 2243
#
# thread-4001 - document 4246
#
# thread-3001 - document 3245thread-1001 - document 1247
#  thread-2001 - document 2244
#
# thread-4001 - document 4247thread-1 - document 250
# thread-3001 - document 3246thread-1001 - document 1248
#
# thread-2001 - document 2245
#
# thread-4001 - document 4248thread-1 - document 251
# thread-3001 - document 3247thread-1001 - document 1249
#
# thread-2001 - document 2246
#
# thread-4001 - document 4249thread-1 - document 252
# thread-3001 - document 3248thread-1001 - document 1250
#
# thread-2001 - document 2247
#
# thread-4001 - document 4250thread-1 - document 253
#  thread-1001 - document 1251
#
# thread-2001 - document 2248thread-3001 - document 3249
# thread-4001 - document 4251thread-1 - document 254
#
# thread-1001 - document 1252
#
# thread-2001 - document 2249thread-3001 - document 3250
# thread-4001 - document 4252thread-1 - document 255
#
#
#
# thread-2001 - document 2250thread-3001 - document 3251thread-1001 - document 1253thread-4001 - document 4253thread-1 - document 256
#
#
#
#
# thread-2001 - document 2251thread-3001 - document 3252 thread-4001 - document 4254thread-1 - document 257
#
# thread-1001 - document 1254
#
# thread-2001 - document 2252thread-3001 - document 3253
# thread-4001 - document 4255
#
# thread-1001 - document 1255
# thread-1 - document 258thread-2001 - document 2253thread-3001 - document 3254
# thread-4001 - document 4256
#
#
# thread-1001 - document 1256
#   thread-3001 - document 3255
# thread-4001 - document 4257thread-1 - document 259thread-2001 - document 2254
# thread-1001 - document 1257
#
#
# thread-3001 - document 3256
# thread-4001 - document 4258thread-1 - document 260thread-2001 - document 2255
# thread-1001 - document 1258
#
#
# thread-3001 - document 3257
# thread-4001 - document 4259thread-1 - document 261thread-2001 - document 2256
# thread-1001 - document 1259
#
#
# thread-3001 - document 3258
# thread-4001 - document 4260thread-1 - document 262thread-2001 - document 2257
#
#
#
# thread-3001 - document 3259thread-1001 - document 1260thread-4001 - document 4261thread-1 - document 263thread-2001 - document 2258
#
#
#
#
# thread-3001 - document 3260thread-1001 - document 1261thread-4001 - document 4262thread-1 - document 264thread-2001 - document 2259
#
#
#
#
# thread-3001 - document 3261thread-1001 - document 1262thread-4001 - document 4263thread-1 - document 265thread-2001 - document 2260
#
#
#
#
# thread-3001 - document 3262 thread-4001 - document 4264 thread-2001 - document 2261
# thread-1001 - document 1263
# thread-1 - document 266
# thread-3001 - document 3263
# thread-4001 - document 4265
#
# thread-1001 - document 1264
# thread-1 - document 267thread-2001 - document 2262thread-3001 - document 3264
# thread-4001 - document 4266
#
#
# thread-1001 - document 1265
# thread-1 - document 268 thread-3001 - document 3265
#
# thread-2001 - document 2263
# thread-1001 - document 1266thread-4001 - document 4267
# thread-3001 - document 3266
#
# thread-1 - document 269thread-2001 - document 2264
# thread-1001 - document 1267thread-4001 - document 4268
#
# thread-3001 - document 3267
#
# thread-1 - document 270thread-2001 - document 2265
# thread-1001 - document 1268thread-4001 - document 4269
#
# thread-3001 - document 3268
#
#  thread-2001 - document 2266
# thread-1001 - document 1269thread-4001 - document 4270thread-1 - document 271
# thread-3001 - document 3269
#
#
# thread-2001 - document 2267
# thread-1001 - document 1270thread-4001 - document 4271
#
#
# thread-1 - document 272thread-2001 - document 2268thread-3001 - document 3270thread-1001 - document 1271thread-4001 - document 4272
#
#
#
#
# thread-1 - document 273thread-2001 - document 2269thread-3001 - document 3271thread-1001 - document 1272thread-4001 - document 4273
#
#
#
#
# thread-1 - document 274thread-2001 - document 2270thread-3001 - document 3272thread-1001 - document 1273thread-4001 - document 4274
#
#
#
#
# thread-1 - document 275 thread-3001 - document 3273thread-1001 - document 1274thread-4001 - document 4275
# thread-2001 - document 2271
#
#
#
# thread-3001 - document 3274thread-1001 - document 1275thread-4001 - document 4276thread-1 - document 276
#
#
#
# thread-2001 - document 2272thread-3001 - document 3275thread-1001 - document 1276thread-4001 - document 4277thread-1 - document 277
#
#
#
#
#  thread-3001 - document 3276thread-1001 - document 1277thread-4001 - document 4278thread-1 - document 278thread-2001 - document 2273
#
#
#
#
# thread-3001 - document 3277thread-1001 - document 1278thread-4001 - document 4279thread-1 - document 279
#
#
#
# thread-2001 - document 2274thread-3001 - document 3278thread-1001 - document 1279thread-4001 - document 4280thread-1 - document 280
#
#
#
#
# thread-2001 - document 2275thread-3001 - document 3279 thread-4001 - document 4281thread-1 - document 281
#
# thread-1001 - document 1280
#
# thread-2001 - document 2276
# thread-4001 - document 4282thread-1 - document 282
# thread-3001 - document 3280thread-1001 - document 1281
#
# thread-2001 - document 2277
#
# thread-4001 - document 4283thread-1 - document 283
# thread-3001 - document 3281thread-1001 - document 1282
#
# thread-2001 - document 2278
#
# thread-4001 - document 4284thread-1 - document 284
#  thread-1001 - document 1283
#
# thread-2001 - document 2279thread-3001 - document 3282
# thread-4001 - document 4285
#
# thread-1001 - document 1284
# thread-1 - document 285thread-2001 - document 2280thread-3001 - document 3283
# thread-4001 - document 4286
#
#
# thread-1001 - document 1285
# thread-1 - document 286thread-2001 - document 2281thread-3001 - document 3284
# thread-4001 - document 4287
#
#
#
#    thread-1001 - document 1286thread-4001 - document 4288thread-1 - document 287thread-2001 - document 2282thread-3001 - document 3285
#
#
#
#
# thread-1001 - document 1287thread-4001 - document 4289thread-1 - document 288thread-2001 - document 2283thread-3001 - document 3286
#
#
#
#
#  thread-4001 - document 4290thread-1 - document 289thread-2001 - document 2284thread-3001 - document 3287thread-1001 - document 1288
#
#
#
#
# thread-4001 - document 4291thread-1 - document 290thread-2001 - document 2285 thread-1001 - document 1289
#
#
# thread-3001 - document 3288
# thread-4001 - document 4292thread-1 - document 291thread-2001 - document 2286
# thread-1001 - document 1290
#
#
# thread-3001 - document 3289
# thread-4001 - document 4293thread-1 - document 292thread-2001 - document 2287
# thread-1001 - document 1291
#
#
# thread-3001 - document 3290
# thread-4001 - document 4294thread-1 - document 293thread-2001 - document 2288
# thread-1001 - document 1292
#
#
#
# thread-4001 - document 4295thread-1 - document 294 thread-3001 - document 3291thread-1001 - document 1293
#
# thread-2001 - document 2289
#
# thread-4001 - document 4296thread-1 - document 295
# thread-3001 - document 3292thread-1001 - document 1294
#
# thread-2001 - document 2290
#
# thread-4001 - document 4297thread-1 - document 296
# thread-3001 - document 3293thread-1001 - document 1295
#
# thread-2001 - document 2291
#
#
# thread-3001 - document 3294thread-1001 - document 1296thread-4001 - document 4298thread-1 - document 297thread-2001 - document 2292
#
#
#
#
# thread-3001 - document 3295thread-1001 - document 1297thread-4001 - document 4299thread-1 - document 298
#
#
#
# thread-2001 - document 2293thread-3001 - document 3296thread-1001 - document 1298thread-4001 - document 4300thread-1 - document 299
#
#
#
#
# thread-2001 - document 2294thread-3001 - document 3297thread-1001 - document 1299thread-4001 - document 4301thread-1 - document 300
#
#
#
#
# thread-2001 - document 2295thread-3001 - document 3298 thread-4001 - document 4302thread-1 - document 301
#
# thread-1001 - document 1300
#
# thread-2001 - document 2296thread-3001 - document 3299
# thread-4001 - document 4303thread-1 - document 302
#
#
#
# thread-2001 - document 2297thread-3001 - document 3300thread-1001 - document 1301thread-4001 - document 4304thread-1 - document 303
#
#
#
#
# thread-2001 - document 2298thread-3001 - document 3301 thread-4001 - document 4305thread-1 - document 304
#
# thread-1001 - document 1302
#
# thread-2001 - document 2299
# thread-4001 - document 4306thread-1 - document 305
# thread-3001 - document 3302thread-1001 - document 1303
#
# thread-2001 - document 2300
#
# thread-4001 - document 4307
#  thread-1001 - document 1304
# thread-1 - document 306thread-2001 - document 2301thread-3001 - document 3303
# thread-4001 - document 4308
#
#
# thread-1001 - document 1305
#  thread-2001 - document 2302thread-3001 - document 3304
#  thread-1 - document 307
#
# thread-1001 - document 1306thread-4001 - document 4309
#  thread-3001 - document 3305
#
# thread-1 - document 308thread-2001 - document 2303
# thread-1001 - document 1307thread-4001 - document 4310
#
# thread-3001 - document 3306
#
# thread-1 - document 309thread-2001 - document 2304
# thread-1001 - document 1308thread-4001 - document 4311
#
# thread-3001 - document 3307
#
# thread-1 - document 310thread-2001 - document 2305
# thread-1001 - document 1309
#
#
# thread-4001 - document 4312thread-1 - document 311thread-2001 - document 2306thread-3001 - document 3308
#
#
#
# thread-1001 - document 1310thread-4001 - document 4313thread-1 - document 312thread-2001 - document 2307thread-3001 - document 3309
#
#
#
#
# thread-1001 - document 1311thread-4001 - document 4314thread-1 - document 313thread-2001 - document 2308thread-3001 - document 3310
#
#
#
#
# thread-1001 - document 1312thread-4001 - document 4315thread-1 - document 314thread-2001 - document 2309
#
#
#
# thread-3001 - document 3311thread-1001 - document 1313thread-4001 - document 4316thread-1 - document 315thread-2001 - document 2310
#
#
#
#
# thread-3001 - document 3312thread-1001 - document 1314thread-4001 - document 4317thread-1 - document 316thread-2001 - document 2311
#
#
#
#
# thread-3001 - document 3313thread-1001 - document 1315thread-4001 - document 4318thread-1 - document 317thread-2001 - document 2312
#
#
#
#
# thread-3001 - document 3314thread-1001 - document 1316thread-4001 - document 4319 thread-2001 - document 2313
#
#
# thread-1 - document 318
# thread-3001 - document 3315thread-1001 - document 1317thread-4001 - document 4320
# thread-2001 - document 2314
#
#
# thread-1 - document 319
# thread-3001 - document 3316thread-1001 - document 1318thread-4001 - document 4321
# thread-2001 - document 2315
#
#
#
# thread-3001 - document 3317thread-1001 - document 1319thread-4001 - document 4322thread-1 - document 320thread-2001 - document 2316
#
#
#
#
# thread-3001 - document 3318  thread-1 - document 321thread-2001 - document 2317
# thread-1001 - document 1320thread-4001 - document 4323
#
# thread-3001 - document 3319
#
# thread-1 - document 322thread-2001 - document 2318
# thread-1001 - document 1321thread-4001 - document 4324
#
#
#
# thread-1 - document 323thread-2001 - document 2319thread-3001 - document 3320thread-1001 - document 1322thread-4001 - document 4325
#
#
#
#
# thread-1 - document 324thread-2001 - document 2320 thread-1001 - document 1323thread-4001 - document 4326
#
# thread-3001 - document 3321
#
# thread-1 - document 325thread-2001 - document 2321
# thread-1001 - document 1324thread-4001 - document 4327
#
# thread-3001 - document 3322
#
# thread-1 - document 326
# thread-1001 - document 1325
# thread-2001 - document 2322thread-3001 - document 3323
# thread-4001 - document 4328thread-1 - document 327
#
#
#
# thread-2001 - document 2323thread-3001 - document 3324thread-1001 - document 1326 thread-1 - document 328
#
#
# thread-4001 - document 4329
# thread-2001 - document 2324thread-3001 - document 3325thread-1001 - document 1327
#
#
#
# thread-4001 - document 4330thread-1 - document 329thread-2001 - document 2325 thread-1001 - document 1328
#
#
# thread-3001 - document 3326
# thread-4001 - document 4331thread-1 - document 330thread-2001 - document 2326
# thread-1001 - document 1329
#
#
# thread-3001 - document 3327
# thread-4001 - document 4332thread-1 - document 331thread-2001 - document 2327
# thread-1001 - document 1330
#
#
# thread-3001 - document 3328
# thread-4001 - document 4333thread-1 - document 332thread-2001 - document 2328
# thread-1001 - document 1331
#
#
# thread-3001 - document 3329
# thread-4001 - document 4334thread-1 - document 333thread-2001 - document 2329
# thread-1001 - document 1332
#
#
# thread-3001 - document 3330
# thread-4001 - document 4335thread-1 - document 334thread-2001 - document 2330
# thread-1001 - document 1333
#
#
#
# thread-4001 - document 4336thread-1 - document 335thread-2001 - document 2331thread-3001 - document 3331thread-1001 - document 1334
#
#
#
#
# thread-4001 - document 4337 thread-2001 - document 2332thread-3001 - document 3332thread-1001 - document 1335
# thread-1 - document 336
#
#
# thread-4001 - document 4338
# thread-2001 - document 2333thread-3001 - document 3333thread-1001 - document 1336
# thread-1 - document 337
#
#
# thread-4001 - document 4339
# thread-2001 - document 2334thread-3001 - document 3334thread-1001 - document 1337
#
#
#
# thread-4001 - document 4340thread-1 - document 338thread-2001 - document 2335thread-3001 - document 3335thread-1001 - document 1338
#
#
#
#
# thread-4001 - document 4341thread-1 - document 339thread-2001 - document 2336thread-3001 - document 3336
#
#
#
# thread-1001 - document 1339thread-4001 - document 4342thread-1 - document 340thread-2001 - document 2337thread-3001 - document 3337
#
#
#
#
# thread-1001 - document 1340 thread-1 - document 341thread-2001 - document 2338thread-3001 - document 3338
# thread-4001 - document 4343
#
#
# thread-1001 - document 1341
# thread-1 - document 342thread-2001 - document 2339thread-3001 - document 3339
# thread-4001 - document 4344
#
#
# thread-1001 - document 1342
# thread-1 - document 343thread-2001 - document 2340thread-3001 - document 3340
# thread-4001 - document 4345
#
#
#
# thread-1 - document 344thread-2001 - document 2341 thread-1001 - document 1343thread-4001 - document 4346
#
# thread-3001 - document 3341
#
# thread-1 - document 345
# thread-1001 - document 1344thread-4001 - document 4347
# thread-2001 - document 2342
#
# thread-1 - document 346
# thread-3001 - document 3342 thread-4001 - document 4348
# thread-2001 - document 2343
# thread-1001 - document 1345
# thread-1 - document 347
# thread-3001 - document 3343
# thread-4001 - document 4349
# thread-2001 - document 2344
# thread-1001 - document 1346
# thread-1 - document 348
# thread-3001 - document 3344
# thread-4001 - document 4350
# thread-2001 - document 2345
# thread-1001 - document 1347
# thread-1 - document 349
# thread-3001 - document 3345
# thread-4001 - document 4351
# thread-2001 - document 2346
# thread-1001 - document 1348
#
# thread-3001 - document 3346
# thread-4001 - document 4352thread-1 - document 350thread-2001 - document 2347
# thread-1001 - document 1349
#
#
# thread-3001 - document 3347
# thread-4001 - document 4353thread-1 - document 351thread-2001 - document 2348
# thread-1001 - document 1350
#
#
#
# ...
# thread-1 - document 43853
#
# thread-1001 - document 44849
# thread-2001 - document 45845thread-3001 - document 46851
# thread-1 - document 43854
#
# thread-1001 - document 44850
# thread-2001 - document 45846thread-3001 - document 46852
# thread-1 - document 43855
#
# thread-1001 - document 44851
# thread-2001 - document 45847thread-3001 - document 46853
# thread-1 - document 43856
#
#
# thread-2001 - document 45848thread-3001 - document 46854thread-1001 - document 44852thread-1 - document 43857
#
#
#
# thread-2001 - document 45849thread-3001 - document 46855thread-1001 - document 44853thread-1 - document 43858
#
#
#
# thread-2001 - document 45850 thread-1001 - document 44854thread-1 - document 43859
# thread-3001 - document 46856
#
# thread-2001 - document 45851
# thread-1001 - document 44855thread-1 - document 43860
# thread-3001 - document 46857
#
#
# thread-1001 - document 44856thread-1 - document 43861thread-2001 - document 45852thread-3001 - document 46858
#
#
#
#  thread-1 - document 43862thread-2001 - document 45853thread-3001 - document 46859thread-1001 - document 44857
#
#
#
# thread-1 - document 43863thread-2001 - document 45854thread-3001 - document 46860thread-1001 - document 44858
#
#
#
# thread-1 - document 43864thread-2001 - document 45855thread-3001 - document 46861thread-1001 - document 44859
#
#
#
# thread-1 - document 43865thread-2001 - document 45856 thread-1001 - document 44860
#
# thread-3001 - document 46862
# thread-1 - document 43866thread-2001 - document 45857
# thread-1001 - document 44861
#
# thread-3001 - document 46863
#  thread-2001 - document 45858
# thread-1001 - document 44862thread-1 - document 43867
# thread-3001 - document 46864
#
# thread-2001 - document 45859
# thread-1001 - document 44863thread-1 - document 43868
#
#
# thread-2001 - document 45860thread-3001 - document 46865thread-1001 - document 44864thread-1 - document 43869
#
#
#
#  thread-3001 - document 46866  thread-2001 - document 45861
# thread-1001 - document 44865thread-1 - document 43870
# thread-3001 - document 46867
#
# thread-2001 - document 45862
# thread-1001 - document 44866thread-1 - document 43871
# thread-3001 - document 46868
#
# thread-2001 - document 45863
# thread-1001 - document 44867thread-1 - document 43872
# thread-3001 - document 46869
#
# thread-2001 - document 45864
# thread-1001 - document 44868thread-1 - document 43873
# thread-3001 - document 46870
#
# thread-2001 - document 45865
# thread-1001 - document 44869thread-1 - document 43874
# thread-3001 - document 46871
#
# thread-2001 - document 45866
# thread-1001 - document 44870thread-1 - document 43875
# thread-3001 - document 46872
#
# thread-2001 - document 45867
# thread-1001 - document 44871thread-1 - document 43876
# thread-3001 - document 46873
#
# thread-2001 - document 45868
#  thread-1 - document 43877
# thread-3001 - document 46874thread-1001 - document 44872
# thread-2001 - document 45869
#
# thread-1 - document 43878
# thread-3001 - document 46875thread-1001 - document 44873
# thread-2001 - document 45870
#
# thread-1 - document 43879
# thread-3001 - document 46876thread-1001 - document 44874
# thread-2001 - document 45871
#
# thread-1 - document 43880
# thread-3001 - document 46877thread-1001 - document 44875
# thread-2001 - document 45872
#
# thread-1 - document 43881
#
# thread-2001 - document 45873thread-3001 - document 46878thread-1001 - document 44876thread-1 - document 43882
#
#
#
#  thread-3001 - document 46879 thread-1 - document 43883thread-2001 - document 45874
# thread-1001 - document 44877
#
# thread-3001 - document 46880
# thread-1 - document 43884thread-2001 - document 45875
# thread-1001 - document 44878
#
# thread-3001 - document 46881
# thread-1 - document 43885thread-2001 - document 45876
# thread-1001 - document 44879
#
#
# thread-1 - document 43886thread-2001 - document 45877thread-3001 - document 46882thread-1001 - document 44880
#
#
#
# thread-1 - document 43887thread-2001 - document 45878thread-3001 - document 46883thread-1001 - document 44881
#
#
#
# thread-1 - document 43888thread-2001 - document 45879thread-3001 - document 46884thread-1001 - document 44882
#
#
#
# thread-1 - document 43889thread-2001 - document 45880thread-3001 - document 46885
#
#
# thread-1001 - document 44883thread-1 - document 43890thread-2001 - document 45881thread-3001 - document 46886
#
#
#
# thread-1001 - document 44884thread-1 - document 43891thread-2001 - document 45882thread-3001 - document 46887
#
#
#
# thread-1001 - document 44885thread-1 - document 43892thread-2001 - document 45883thread-3001 - document 46888
#
#
#
# thread-1001 - document 44886thread-1 - document 43893thread-2001 - document 45884thread-3001 - document 46889
#
#
#
# thread-1001 - document 44887thread-1 - document 43894 thread-3001 - document 46890
#
# thread-2001 - document 45885
#  thread-1 - document 43895
# thread-3001 - document 46891thread-1001 - document 44888
# thread-2001 - document 45886
#
# thread-1 - document 43896
#  thread-1001 - document 44889
#  thread-3001 - document 46892
# thread-1 - document 43897thread-2001 - document 45887
# thread-1001 - document 44890
#
# thread-3001 - document 46893
# thread-1 - document 43898thread-2001 - document 45888
# thread-1001 - document 44891
#
# thread-3001 - document 46894
# thread-1 - document 43899thread-2001 - document 45889
# thread-1001 - document 44892
#
# thread-3001 - document 46895
# thread-1 - document 43900thread-2001 - document 45890
# thread-1001 - document 44893
#
#
# thread-1 - document 43901thread-2001 - document 45891thread-3001 - document 46896thread-1001 - document 44894
#
#
#
#  thread-2001 - document 45892thread-3001 - document 46897thread-1001 - document 44895thread-1 - document 43902
#
#
#
# thread-2001 - document 45893thread-3001 - document 46898thread-1001 - document 44896thread-1 - document 43903
#
#
#
# thread-2001 - document 45894thread-3001 - document 46899thread-1001 - document 44897thread-1 - document 43904
#
#
#
# thread-2001 - document 45895 thread-1001 - document 44898
# thread-3001 - document 46900
# thread-1 - document 43905
#
# thread-2001 - document 45896thread-3001 - document 46901thread-1001 - document 44899thread-1 - document 43906
#
#
#
# thread-2001 - document 45897thread-3001 - document 46902thread-1001 - document 44900thread-1 - document 43907
#
#
#
# thread-2001 - document 45898thread-3001 - document 46903thread-1001 - document 44901thread-1 - document 43908
#
#
#
# thread-2001 - document 45899thread-3001 - document 46904thread-1001 - document 44902thread-1 - document 43909
#
#
#
#  thread-3001 - document 46905thread-1001 - document 44903 thread-2001 - document 45900
#
# thread-1 - document 43910
#  thread-1001 - document 44904
# thread-2001 - document 45901thread-3001 - document 46906
# thread-1 - document 43911
#
# thread-1001 - document 44905
# thread-2001 - document 45902thread-3001 - document 46907
#
#
# thread-1001 - document 44906thread-1 - document 43912thread-2001 - document 45903thread-3001 - document 46908
#
#
#
# thread-1001 - document 44907thread-1 - document 43913thread-2001 - document 45904thread-3001 - document 46909
#
#
#
# thread-1001 - document 44908thread-1 - document 43914thread-2001 - document 45905thread-3001 - document 46910
#
#
#
# thread-1001 - document 44909thread-1 - document 43915thread-2001 - document 45906thread-3001 - document 46911
#
#
#
#  thread-1 - document 43916thread-2001 - document 45907thread-3001 - document 46912thread-1001 - document 44910
#
#
#
# thread-1 - document 43917  thread-1001 - document 44911
# thread-2001 - document 45908thread-3001 - document 46913
#
#
#  thread-1 - document 43918thread-2001 - document 45909thread-3001 - document 46914thread-1001 - document 44912
#
#
#
# thread-1 - document 43919thread-2001 - document 45910thread-3001 - document 46915thread-1001 - document 44913
#
#
#
#  thread-2001 - document 45911thread-3001 - document 46916thread-1001 - document 44914thread-1 - document 43920
#
#
#
# thread-2001 - document 45912thread-3001 - document 46917thread-1001 - document 44915thread-1 - document 43921
#
#
#
# thread-2001 - document 45913 thread-1001 - document 44916thread-1 - document 43922
# thread-3001 - document 46918
#
# thread-2001 - document 45914
#
# thread-3001 - document 46919thread-1001 - document 44917thread-1 - document 43923
#
#
# thread-2001 - document 45915thread-3001 - document 46920thread-1001 - document 44918
#
#
# thread-1 - document 43924thread-2001 - document 45916thread-3001 - document 46921thread-1001 - document 44919
#
#
#
# thread-1 - document 43925thread-2001 - document 45917thread-3001 - document 46922thread-1001 - document 44920
#
#
#
# thread-1 - document 43926thread-2001 - document 45918
#
# thread-3001 - document 46923thread-1001 - document 44921 thread-2001 - document 45919
#
# thread-1 - document 43927
# thread-3001 - document 46924thread-1001 - document 44922
# thread-2001 - document 45920
#
#
# thread-3001 - document 46925thread-1001 - document 44923thread-1 - document 43928thread-2001 - document 45921
#
#
#
# thread-3001 - document 46926thread-1001 - document 44924thread-1 - document 43929thread-2001 - document 45922
#
#
#
#  thread-1001 - document 44925thread-1 - document 43930thread-2001 - document 45923thread-3001 - document 46927
#
#
#
# thread-1001 - document 44926 thread-2001 - document 45924thread-3001 - document 46928
# thread-1 - document 43931
#
# thread-1001 - document 44927
# thread-2001 - document 45925thread-3001 - document 46929
# thread-1 - document 43932
#
# thread-1001 - document 44928
# thread-2001 - document 45926
# thread-1 - document 43933
# thread-3001 - document 46930thread-1001 - document 44929
# thread-2001 - document 45927
#
# thread-1 - document 43934
#  thread-1001 - document 44930
# thread-2001 - document 45928thread-3001 - document 46931
# thread-1 - document 43935
#
# thread-1001 - document 44931
# thread-2001 - document 45929thread-3001 - document 46932
# thread-1 - document 43936
#
# thread-1001 - document 44932
# thread-2001 - document 45930thread-3001 - document 46933
# thread-1 - document 43937
#
# thread-1001 - document 44933
# thread-2001 - document 45931thread-3001 - document 46934
#
#
# thread-1001 - document 44934thread-1 - document 43938thread-2001 - document 45932thread-3001 - document 46935
#
#
#
#  thread-1 - document 43939thread-2001 - document 45933thread-3001 - document 46936thread-1001 - document 44935
#
#
#
#  thread-2001 - document 45934thread-3001 - document 46937 thread-1 - document 43940
#
# thread-1001 - document 44936
# thread-2001 - document 45935thread-3001 - document 46938
# thread-1 - document 43941
#
# thread-1001 - document 44937
# thread-2001 - document 45936thread-3001 - document 46939
# thread-1 - document 43942
#
#
# thread-2001 - document 45937thread-3001 - document 46940thread-1001 - document 44938thread-1 - document 43943
#
#
#
# thread-2001 - document 45938thread-3001 - document 46941thread-1001 - document 44939thread-1 - document 43944
#
#
#
# thread-2001 - document 45939thread-3001 - document 46942
#
# thread-1001 - document 44940thread-1 - document 43945thread-2001 - document 45940thread-3001 - document 46943
#
#
#
# thread-1001 - document 44941thread-1 - document 43946thread-2001 - document 45941thread-3001 - document 46944
#
#
#
# thread-1001 - document 44942 thread-2001 - document 45942thread-3001 - document 46945
# thread-1 - document 43947
#
# thread-1001 - document 44943
#
# thread-1 - document 43948thread-2001 - document 45943thread-3001 - document 46946thread-1001 - document 44944
#
#
#
# thread-1 - document 43949thread-2001 - document 45944thread-3001 - document 46947thread-1001 - document 44945
#
#
#
# thread-1 - document 43950thread-2001 - document 45945thread-3001 - document 46948thread-1001 - document 44946
#
#
#
# thread-1 - document 43951thread-2001 - document 45946thread-3001 - document 46949thread-1001 - document 44947
#
#
#
# thread-1 - document 43952 thread-3001 - document 46950
# thread-2001 - document 45947
# thread-1001 - document 44948thread-1 - document 43953
# thread-3001 - document 46951
#
# thread-2001 - document 45948
# thread-1001 - document 44949thread-1 - document 43954
# thread-3001 - document 46952
#
#
# thread-1001 - document 44950thread-1 - document 43955thread-2001 - document 45949thread-3001 - document 46953
#
#
#
# thread-1001 - document 44951thread-1 - document 43956thread-2001 - document 45950thread-3001 - document 46954
#
#
#
# thread-1001 - document 44952thread-1 - document 43957thread-2001 - document 45951thread-3001 - document 46955
#
#
#
# thread-1001 - document 44953thread-1 - document 43958thread-2001 - document 45952thread-3001 - document 46956
#
#
#
# thread-1001 - document 44954thread-1 - document 43959thread-2001 - document 45953thread-3001 - document 46957
#
#
#
# thread-1001 - document 44955thread-1 - document 43960thread-2001 - document 45954thread-3001 - document 46958
#
#
#
# thread-1001 - document 44956thread-1 - document 43961thread-2001 - document 45955thread-3001 - document 46959
#
#
#
# thread-1001 - document 44957thread-1 - document 43962thread-2001 - document 45956thread-3001 - document 46960
#
#
#
# thread-1001 - document 44958thread-1 - document 43963thread-2001 - document 45957thread-3001 - document 46961
#
#
#
# thread-1001 - document 44959thread-1 - document 43964thread-2001 - document 45958thread-3001 - document 46962
#
#
#
# thread-1001 - document 44960thread-1 - document 43965thread-2001 - document 45959thread-3001 - document 46963
#
#
#
# thread-1001 - document 44961thread-1 - document 43966thread-2001 - document 45960thread-3001 - document 46964
#
#
#
# thread-1001 - document 44962 thread-2001 - document 45961thread-3001 - document 46965
# thread-1 - document 43967
#
# thread-1001 - document 44963
# thread-2001 - document 45962thread-3001 - document 46966
# thread-1 - document 43968
#
# thread-1001 - document 44964
# thread-2001 - document 45963thread-3001 - document 46967
# thread-1 - document 43969
#
# thread-1001 - document 44965
# thread-2001 - document 45964thread-3001 - document 46968
# thread-1 - document 43970
#
# thread-1001 - document 44966
# thread-2001 - document 45965thread-3001 - document 46969
# thread-1 - document 43971
#
# thread-1001 - document 44967
# thread-2001 - document 45966thread-3001 - document 46970
# thread-1 - document 43972
#
#
# thread-2001 - document 45967thread-3001 - document 46971thread-1001 - document 44968
#
#
# thread-1 - document 43973thread-2001 - document 45968thread-3001 - document 46972thread-1001 - document 44969
#
#
#
# thread-1 - document 43974thread-2001 - document 45969thread-3001 - document 46973
#
#
# thread-1001 - document 44970 thread-2001 - document 45970thread-3001 - document 46974
# thread-1 - document 43975
#
# thread-1001 - document 44971
# thread-2001 - document 45971
# thread-1 - document 43976
# thread-3001 - document 46975thread-1001 - document 44972
# thread-2001 - document 45972
#
# thread-1 - document 43977
# thread-3001 - document 46976thread-1001 - document 44973
# thread-2001 - document 45973
#
# thread-1 - document 43978
# thread-3001 - document 46977thread-1001 - document 44974
# thread-2001 - document 45974
#
# thread-1 - document 43979
# thread-3001 - document 46978
# thread-2001 - document 45975
# thread-1001 - document 44975
# thread-3001 - document 46979
# thread-1 - document 43980thread-2001 - document 45976
# thread-1001 - document 44976
#
# thread-3001 - document 46980
#  thread-2001 - document 45977
# thread-1001 - document 44977thread-1 - document 43981
# thread-3001 - document 46981
#
# thread-2001 - document 45978
#
#  thread-1001 - document 44978thread-1 - document 43982thread-2001 - document 45979thread-3001 - document 46982
#
#
#
# thread-1001 - document 44979 thread-2001 - document 45980
# thread-1 - document 43983
# thread-3001 - document 46983thread-1001 - document 44980
# thread-2001 - document 45981
#
# thread-1 - document 43984
#  thread-1001 - document 44981
# thread-2001 - document 45982thread-3001 - document 46984
# thread-1 - document 43985
#
# thread-1001 - document 44982
# thread-2001 - document 45983thread-3001 - document 46985
# thread-1 - document 43986
#
# thread-1001 - document 44983
# thread-2001 - document 45984
# thread-1 - document 43987
# thread-3001 - document 46986thread-1001 - document 44984
# thread-2001 - document 45985
#
# Total time for thread-1: 14.626000s
#
# thread-3001 - document 46987
# thread-2001 - document 45986
# thread-1001 - document 44985
# Total time for thread-3001: 14.593000s
#
# thread-2001 - document 45987
# thread-1001 - document 44986
# Total time for thread-2001: 14.619000s
#
#
# thread-1001 - document 44987
# Total time for thread-1001: 14.627000s
#
# Done replace_content_by_index in 352.487000s
#
# TOTAL TIME FOR TOPIC 'kinh-doanh': 367.632000s
