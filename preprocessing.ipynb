# %% [markdown]
# # Preprocessing
# 1. Remove stop word
# 2. Create dictionary - order is not important --> save file
# 3. Calculate tf-idf for each document --> filter top 400 words
# 4. Replace word by index (of dictionary) - KEEP order
# 5. Create a array of sequences - each sequence is a document --> save file

# %%
import os
import pandas as pd
from nltk import word_tokenize
import time
import nltk
import itertools
import operator
import codecs
from sklearn.feature_extraction.text import TfidfVectorizer
import heapq
import numpy as np
import re
import threading
import bottleneck as bn

# %%
def clean_str(string):
    """
    Remove ending character such as .,?;!:
    """
    endings = ['.', '?', ',', '!', ':', ';', '`']
    while len(string) > 0 and string[-1] in endings:
        string = string[:-1]
    
    return string.strip().lower()

# %%
def is_string(string):
    return not (re.match('(\d{1,})', string)
                or re.match('(\d{1,},\d{1,})', string) 
                or re.match('(\d{1,}/\d{1,})', string) 
                or re.match('(\d{1,}.\d{1,})', string))

# %% [markdown]
# ### Load data - split sentences to words and lowercase

# %%
df = pd.read_csv('data/1_data.csv', encoding='utf-8')

# %%
# split sentences to word
start_time = time.time()
df['tokens'] = df['content'].apply(lambda x: word_tokenize(x))
print('Finish spliting sentences into words: %f s' % (time.time() - start_time))
# Out:
# Finish spliting sentences into words: 123.785000 s

# %%
df.head()
# Out:
#                                              content     label  \
# 0  Nhà_vua và Hoàng_hậu Nhật_Bản thăm Cố_đô Huế Đ...  the-gioi
# 1  Chiếc tuần_dương_hạm ngầm xấu_số của hải_quân ...  the-gioi
# 2  Máy_bay chở gia_đình Bin_Laden rơi vì hạ_cánh ...  the-gioi
# 3  Putin gửi lời chúc tới Trump không nhắc đến Ob...  the-gioi
# 4  Trump không đưa Nga vào danh_sách ưu_tiên của ...  the-gioi
#
#                                               tokens
# 0  [Nhà_vua, và, Hoàng_hậu, Nhật_Bản, thăm, Cố_đô...
# 1  [Chiếc, tuần_dương_hạm, ngầm, xấu_số, của, hải...
# 2  [Máy_bay, chở, gia_đình, Bin_Laden, rơi, vì, h...
# 3  [Putin, gửi, lời, chúc, tới, Trump, không, nhắ...
# 4  [Trump, không, đưa, Nga, vào, danh_sách, ưu_ti...

# %%
# Remove single-character tokens (mostly punctuation)
# Remove numbers
# convert all words into lowercase
start_time = time.time()
df['tokens'] = df['tokens'].apply(lambda x: [clean_str(word) for word in x if len(word) > 1 and is_string(word)])

# The last word is often author of document, so we remove it
df['tokens'] = df['tokens'].apply(lambda x: x[:-1])

print('Finish cleaning data: %f s' % (time.time() - start_time))
df.head()
# Out:
# Finish cleaning data: 193.131000 s
#                                              content     label  \
# 0  Nhà_vua và Hoàng_hậu Nhật_Bản thăm Cố_đô Huế Đ...  the-gioi
# 1  Chiếc tuần_dương_hạm ngầm xấu_số của hải_quân ...  the-gioi
# 2  Máy_bay chở gia_đình Bin_Laden rơi vì hạ_cánh ...  the-gioi
# 3  Putin gửi lời chúc tới Trump không nhắc đến Ob...  the-gioi
# 4  Trump không đưa Nga vào danh_sách ưu_tiên của ...  the-gioi
#
#                                               tokens
# 0  [nhà_vua, và, hoàng_hậu, nhật_bản, thăm, cố_đô...
# 1  [chiếc, tuần_dương_hạm, ngầm, xấu_số, của, hải...
# 2  [máy_bay, chở, gia_đình, bin_laden, rơi, vì, h...
# 3  [putin, gửi, lời, chúc, tới, trump, không, nhắ...
# 4  [trump, không, đưa, nga, vào, danh_sách, ưu_ti...

# %%
df['content'] = df['tokens'].apply(lambda x: ' '.join(x))
df.drop('tokens', axis=1, inplace=True)
df.to_csv(os.path.join('data', '2_cleaned_data.csv'), index=False, encoding='utf-8')

# %% [markdown]
# ### Step 1: Remove stopword

# %%
df = pd.read_csv(os.path.join('data', '2_cleaned_data.csv'), encoding='utf-8')
df['content'] = df['content'].apply(lambda x: x.split(' '))
df.head()
# Out:
#                                              content     label
# 0  [nhà_vua, và, hoàng_hậu, nhật_bản, thăm, cố_đô...  the-gioi
# 1  [chiếc, tuần_dương_hạm, ngầm, xấu_số, của, hải...  the-gioi
# 2  [máy_bay, chở, gia_đình, bin_laden, rơi, vì, h...  the-gioi
# 3  [putin, gửi, lời, chúc, tới, trump, không, nhắ...  the-gioi
# 4  [trump, không, đưa, nga, vào, danh_sách, ưu_ti...  the-gioi

# %%
stopwords = []
with codecs.open(os.path.join('data', 'vietnamese-stopwords-dash.txt'), 'r', encoding='utf-8') as f:
    stopwords = f.readlines()

# you may also want to remove whitespace characters like `\n` at the end of each line
stopwords = [x.strip() for x in stopwords]

# %%
print(stopwords[1596])
print(len(df['content'][0]))
# Out:
# và
# 165

# %%
start_time = time.time()
df['content'] = df['content'].apply(lambda x: [word for word in x if word not in stopwords])
print('Finish removing stopwords: %f s' % (time.time() - start_time))
print(len(df['content'][0]))
df.head()
# Out:
# Finish removing stopwords: 700.040000 s
# 106
#                                              content     label
# 0  [nhà_vua, hoàng_hậu, nhật_bản, thăm, cố_đô, hu...  the-gioi
# 1  [tuần_dương_hạm, ngầm, xấu_số, hải_quân, pháp,...  the-gioi
# 2  [máy_bay, chở, gia_đình, bin_laden, rơi, hạ_cá...  the-gioi
# 3  [putin, gửi, chúc, trump, nhắc, obama, thông_đ...  the-gioi
# 4  [trump, nga, danh_sách, ưu_tiên, lầu_năm_góc, ...  the-gioi

# %%
# replace content with new text (remove stopword)
df['content'] = df['content'].apply(lambda x: ' '.join(x))

# %%
df.head()
# Out:
#                                              content     label
# 0  nhà_vua hoàng_hậu nhật_bản thăm cố_đô huế đông...  the-gioi
# 1  tuần_dương_hạm ngầm xấu_số hải_quân pháp tàu_n...  the-gioi
# 2  máy_bay chở gia_đình bin_laden rơi hạ_cánh tốc...  the-gioi
# 3  putin gửi chúc trump nhắc obama thông_điệp tổn...  the-gioi
# 4  trump nga danh_sách ưu_tiên lầu_năm_góc danh_s...  the-gioi

# %%
df.to_csv(os.path.join('data', '3_removed_stopwords_data.csv'), index=False, encoding='utf-8')

# %% [markdown]
# ### Step 1b: add index into document, then split into seperate file to prevent the lack of memory

# %%
df = pd.read_csv(os.path.join('data', '3_removed_stopwords_data.csv'), encoding='utf-8')
df['doc_id'] = range(1, len(df) + 1)
df.head()
# Out:
#                                              content     label  doc_id
# 0  nhà_vua hoàng_hậu nhật_bản thăm cố_đô huế đông...  the-gioi       1
# 1  tuần_dương_hạm ngầm xấu_số hải_quân pháp tàu_n...  the-gioi       2
# 2  máy_bay chở gia_đình bin_laden rơi hạ_cánh tốc...  the-gioi       3
# 3  putin gửi chúc trump nhắc obama thông_điệp tổn...  the-gioi       4
# 4  trump nga danh_sách ưu_tiên lầu_năm_góc danh_s...  the-gioi       5

# %%
df.to_csv(os.path.join('data', '4_index_data.csv'), 
          columns=['doc_id', 'content', 'label'], 
          index=False, encoding='utf-8')

# %%
for topic in df.label.unique():
    df_filter = df[df.label == topic]
    file_name = '4_index_data.%s.csv' % topic
    df_filter.to_csv(os.path.join('data', file_name),
                     columns=['doc_id', 'content', 'label'], 
                     index=False, encoding='utf-8')

# %% [markdown]
# ### Step 2. Calculate tf-idf for each document

# %%
df = pd.read_csv(os.path.join('data', '4_index_data.csv'), encoding='utf-8')
df.head()
# Out:
#    doc_id                                            content     label
# 0       1  nhà_vua hoàng_hậu nhật_bản thăm cố_đô huế đông...  the-gioi
# 1       2  tuần_dương_hạm ngầm xấu_số hải_quân pháp tàu_n...  the-gioi
# 2       3  máy_bay chở gia_đình bin_laden rơi hạ_cánh tốc...  the-gioi
# 3       4  putin gửi chúc trump nhắc obama thông_điệp tổn...  the-gioi
# 4       5  trump nga danh_sách ưu_tiên lầu_năm_góc danh_s...  the-gioi

# %%
start_time = time.time()

corpus = df['content']
vectorizer = TfidfVectorizer(min_df=1)
X = vectorizer.fit_transform(corpus)
words = vectorizer.get_feature_names()

print('Finish calculating tfidf: %f s' % (time.time() - start_time))
# Out:
# Finish calculating tfidf: 13.423000 s

# %%
topics = df['label'].unique()
topics
# Out:
# array([u'the-gioi', u'khoa-hoc', u'du-lich', u'giao-duc', u'the-thao',
#        u'thoi-su', u'phap-luat', u'so-hoa', u'oto-xe-may', u'giai-tri',
#        u'kinh-doanh'], dtype=object)

# %% [markdown]
# ### Step 3. Create dictionary - save file

# %%
sorted_words = sorted(words)
word_to_index = dict([(w, i) for i, w in enumerate(sorted_words)])

with open(os.path.join('data', 'dic_words.txt'), 'w') as f:
    for i, w in enumerate(sorted_words):
        f.write('%s,%s\n' % (w.encode('utf-8'), i))

# %% [markdown]
# ### Step 4. Get top N words - Replace word by index (of dictionary) - KEEP order - then save file

# %%
# ref: http://stackoverflow.com/questions/10337533/a-fast-way-to-find-the-largest-n-elements-in-an-numpy-array
# but I see that numpy works better than bottleneck
start_time = time.time()
bn.argpartition(-X[0,:].toarray()[0], 400)[:400]
print('Total time: %fs' % (time.time() - start_time))
# Out:
# Total time: 0.007000s

# %%
start_time = time.time()
top_index_freq_words = np.argpartition(-X[0,:].toarray()[0], 400).astype(np.int32)

start_time = time.time()
df.loc[0, 'top_words'] = operator.itemgetter(*top_index_freq_words)(words) 
#list(words[top_index_freq_words]) 
#[words[index] for index in top_index_freq_words]
print('Total time: %fs' % (time.time() - start_time))
# Out:
# Total time: 0.118000s

# %%
class TextThread (threading.Thread):
    def __init__(self, thread_id, name, nb_top_words, idx_from, idx_to):
        threading.Thread.__init__(self)
        self.threadID = thread_id
        self.name = name
        self.nb_top_words = nb_top_words
        self.idx_from = idx_from
        self.idx_to = idx_to
    def run(self):
        print("Starting %s - from %d to %d\n" % (self.name, self.idx_from, self.idx_to))        
        get_top_n_words(self.name, self.nb_top_words, self.idx_from, self.idx_to)

# %%
def get_top_n_words(thread_name, nb_top_words, idx_from, idx_to):
    start_time = time.time()
    for i in range(idx_from, idx_to):
        doc_id = df.doc_id[i]
        top_index_freq_words = np.argpartition(-X[doc_id - 1,:].toarray()[0], nb_top_words)[:nb_top_words]
        df.at[i, 'top_words'] = list(operator.itemgetter(*top_index_freq_words)(words))
        print('%s - document %d' % (thread_name, doc_id))
        
    print('Total time for %s: %fs\n' % (thread_name, time.time() - start_time))

# %%
# nb_top_words = 400

# df = pd.read_csv(os.path.join('data', '4_index_data.du-lich.csv'), encoding='utf-8')
# df['top_words'] = None
# start_time = time.time()

# # Create 100 docs per thread
# doc_per_thread = 100
# for i in range(0, len(df), doc_per_thread):
#     # define idx_to
#     if i + doc_per_thread > len(df) - 1:
#         idx_to = len(df) - 1
#     else:
#         idx_to = i + doc_per_thread
    
#     get_top_n_words('thread_name', nb_top_words, i, idx_to)
#     break

# %%
# if word in content belong to top_words, replace it by index of word (in dictionary), otherwise, remove it
def replace_content_by_index():
    start_time = time.time()
    df['content'] = df['content'].apply(lambda x: x.split(' '))
    print('Splitting content into words in %fs\n' % (time.time() - start_time))
    
    start_time = time.time()
    for i in range(0, len(df)):
        if len(df.loc[i, 'top_words']) == 0:
            print('WARN: there is no topwords for doc %d' % i)
            continue

        index_of_top_words = []
        for word in df.loc[i, 'content']:
            if word in df.loc[i, 'top_words']:
                index_of_top_words.append(str(word_to_index[word]))

        df.loc[i, 'content'] = ' '.join(index_of_top_words)

    print('Done replace_content_by_index in %fs\n' % (time.time() - start_time))

# %%
nb_top_words = 400
doc_per_thread = 1000
# for each topic, read corresponding file
del df
for topic in topics:
    df = pd.read_csv(os.path.join('data', ('4_index_data.%s.csv' % topic)), encoding='utf-8')
    df['top_words'] = None

    start_time = time.time()
    threads = []

    # Create 1000 docs per thread
    for i in range(0, len(df), doc_per_thread):
        # define idx_to
        if i + doc_per_thread > len(df) - 1:
            idx_to = len(df)
        else:
            idx_to = i + doc_per_thread
        
        thread = TextThread(i + 1, 'thread-%d' % (i + 1), n, i, idx_to)
        threads.append(thread)
        thread.start()
        
    # Wait for all threads to complete
    for t in threads:
        t.join()

    # replace content by index of top freq words
    replace_content_by_index()
    
    # save result to file
    df.to_csv(os.path.join('data', 'matrix_data.%s.csv' % (topic)), 
              columns=['doc_id', 'content', 'label'],
              index=False, encoding='utf-8')
    print("TOTAL TIME FOR TOPIC '%s': %fs\n" % (topic, time.time() - start_time))
# Out:
# Starting thread-0
#  - from 0 to 1000
# Starting thread-1
#  - from 1000 to 2000Starting thread-2
#  - from 2000 to 3000
#
# Starting thread-3
#  - from 3000 to 4000Starting thread-4
#  - from 4000 to 4479
# thread-0 - document 1thread-1 - document 1001thread-2 - document 2001
# thread-3 - document 3001
#
#
# thread-4 - document 4001
# thread-0 - document 2thread-1 - document 1002thread-2 - document 2002
# thread-3 - document 3002
#
#
# thread-4 - document 4002
# thread-0 - document 3thread-1 - document 1003thread-2 - document 2003
# thread-3 - document 3003
#
#
# thread-4 - document 4003
# thread-0 - document 4 thread-2 - document 2004
# thread-3 - document 3004
# thread-1 - document 1004
# thread-4 - document 4004
# thread-0 - document 5
# thread-2 - document 2005
# thread-3 - document 3005
# thread-1 - document 1005
# thread-4 - document 4005
# thread-0 - document 6
# thread-2 - document 2006
# thread-3 - document 3006
# thread-1 - document 1006
# thread-4 - document 4006
# thread-0 - document 7
# thread-2 - document 2007
# thread-3 - document 3007
# thread-1 - document 1007
# thread-4 - document 4007
# thread-0 - document 8
# thread-2 - document 2008
# thread-3 - document 3008
#
# thread-4 - document 4008
#  thread-1 - document 1008thread-2 - document 2009
# thread-3 - document 3009thread-0 - document 9
#
# thread-4 - document 4009
#
# thread-1 - document 1009thread-2 - document 2010
# thread-3 - document 3010
#
# thread-4 - document 4010
# thread-0 - document 10
# thread-3 - document 3011
# thread-1 - document 1010thread-2 - document 2011thread-4 - document 4011
# thread-0 - document 11
#
#
# thread-3 - document 3012
# thread-1 - document 1011thread-2 - document 2012thread-4 - document 4012
# thread-0 - document 12
#
#
# thread-3 - document 3013
# thread-1 - document 1012thread-2 - document 2013thread-4 - document 4013
# thread-0 - document 13
#
#
# thread-3 - document 3014
# thread-1 - document 1013thread-2 - document 2014thread-4 - document 4014
# thread-0 - document 14
#
# thread-3 - document 3015
#
# thread-2 - document 2015thread-4 - document 4015
# thread-0 - document 15thread-1 - document 1014
#
# thread-3 - document 3016
#
#  thread-4 - document 4016
# thread-0 - document 16thread-1 - document 1015thread-2 - document 2016
# thread-3 - document 3017
#
#
# thread-4 - document 4017
# thread-0 - document 17thread-1 - document 1016thread-2 - document 2017
# thread-3 - document 3018
#
#
# thread-4 - document 4018
# thread-0 - document 18thread-1 - document 1017thread-2 - document 2018
#
#
#
# thread-4 - document 4019thread-3 - document 3019thread-0 - document 19 thread-2 - document 2019
#
#
# thread-1 - document 1018
# thread-4 - document 4020thread-3 - document 3020thread-0 - document 20
# thread-2 - document 2020
#
#
# thread-1 - document 1019
# thread-4 - document 4021 thread-0 - document 21
# thread-2 - document 2021
# thread-3 - document 3021
# thread-1 - document 1020
#
# thread-0 - document 22
# thread-2 - document 2022thread-4 - document 4022thread-3 - document 3022
# thread-1 - document 1021
#
#
# thread-0 - document 23
# thread-2 - document 2023thread-4 - document 4023thread-3 - document 3023
# thread-1 - document 1022
#
#
# thread-0 - document 24
# thread-2 - document 2024 thread-3 - document 3024
# thread-1 - document 1023
# thread-4 - document 4024
# thread-0 - document 25
# thread-2 - document 2025
# thread-3 - document 3025
# thread-1 - document 1024
#
# thread-0 - document 26
#  thread-4 - document 4025thread-3 - document 3026
# thread-1 - document 1025thread-2 - document 2026
#
# thread-0 - document 27
#
#  thread-3 - document 3027
# thread-1 - document 1026thread-2 - document 2027thread-4 - document 4026
# thread-0 - document 28
#
#
# thread-3 - document 3028
# thread-1 - document 1027 thread-4 - document 4027
# thread-0 - document 29
# thread-2 - document 2028
# thread-3 - document 3029
#
# thread-4 - document 4028
#  thread-1 - document 1028thread-2 - document 2029
#  thread-0 - document 30
#
#  thread-3 - document 3030
# thread-1 - document 1029thread-2 - document 2030thread-4 - document 4029
# thread-0 - document 31
#
#
#
# thread-1 - document 1030thread-2 - document 2031thread-4 - document 4030thread-3 - document 3031thread-0 - document 32
#
#
#
#
# thread-1 - document 1031thread-2 - document 2032  thread-0 - document 33
#
# thread-4 - document 4031thread-3 - document 3032
# thread-1 - document 1032thread-2 - document 2033
#
#
#
#  thread-3 - document 3033thread-0 - document 34thread-1 - document 1033thread-2 - document 2034thread-4 - document 4032
#
#
#
#
# thread-3 - document 3034thread-0 - document 35thread-1 - document 1034 thread-4 - document 4033
#
#
# thread-2 - document 2035
# thread-3 - document 3035thread-0 - document 36thread-1 - document 1035
# thread-4 - document 4034
#
#
# thread-2 - document 2036
# thread-3 - document 3036thread-0 - document 37thread-1 - document 1036
# thread-4 - document 4035
#
#
# thread-2 - document 2037
# thread-3 - document 3037thread-0 - document 38thread-1 - document 1037
# thread-4 - document 4036
#
#
# thread-2 - document 2038
#  thread-0 - document 39
# thread-4 - document 4037thread-3 - document 3038
# thread-1 - document 1038thread-2 - document 2039
# thread-0 - document 40
#
#
# thread-3 - document 3039
# thread-1 - document 1039thread-2 - document 2040
# thread-0 - document 41
#
# thread-4 - document 4038thread-3 - document 3040
#
#
# thread-0 - document 42thread-1 - document 1040thread-2 - document 2041thread-4 - document 4039thread-3 - document 3041
#
#
#
#
# thread-0 - document 43thread-1 - document 1041thread-2 - document 2042thread-4 - document 4040thread-3 - document 3042
#
#
#
#
# thread-0 - document 44 thread-2 - document 2043thread-4 - document 4041
# thread-1 - document 1042
#
# thread-3 - document 3043thread-0 - document 45
# thread-2 - document 2044thread-4 - document 4042
#
#
#
# thread-3 - document 3044thread-0 - document 46thread-1 - document 1043thread-2 - document 2045thread-4 - document 4043
#
#
#
#
# thread-3 - document 3045thread-0 - document 47thread-1 - document 1044thread-2 - document 2046thread-4 - document 4044
#
#
#
#
#  thread-0 - document 48thread-1 - document 1045thread-2 - document 2047thread-4 - document 4045thread-3 - document 3046
#
#
#
#
# thread-0 - document 49thread-1 - document 1046thread-2 - document 2048thread-4 - document 4046thread-3 - document 3047
#
#
#
#
# thread-0 - document 50 thread-2 - document 2049thread-4 - document 4047thread-3 - document 3048
# thread-1 - document 1047
#
#
# thread-0 - document 51
# thread-2 - document 2050thread-4 - document 4048thread-3 - document 3049
# thread-1 - document 1048
#
#
#
#  thread-4 - document 4049thread-3 - document 3050thread-0 - document 52 thread-2 - document 2051
#
#
# thread-1 - document 1049
#  thread-3 - document 3051thread-0 - document 53
#  thread-4 - document 4050
#
#  thread-2 - document 2052
# thread-3 - document 3052thread-0 - document 54thread-1 - document 1050
#
#
#
#  thread-4 - document 4051thread-3 - document 3053thread-0 - document 55thread-1 - document 1051thread-2 - document 2053
#
#
#
#
# thread-4 - document 4052thread-3 - document 3054 thread-1 - document 1052
#
# thread-0 - document 56
# thread-2 - document 2054thread-4 - document 4053thread-3 - document 3055
# thread-1 - document 1053
#
#
# thread-0 - document 57
# thread-2 - document 2055thread-4 - document 4054thread-3 - document 3056
#
#
#
# thread-0 - document 58thread-1 - document 1054thread-2 - document 2056thread-4 - document 4055thread-3 - document 3057
#
#
#
#
# thread-0 - document 59thread-1 - document 1055thread-2 - document 2057thread-4 - document 4056
#
#
#
# thread-3 - document 3058thread-0 - document 60thread-1 - document 1056thread-2 - document 2058thread-4 - document 4057
#
#
#
#
# thread-3 - document 3059 thread-1 - document 1057thread-2 - document 2059thread-4 - document 4058
# thread-0 - document 61
#
#
#
#  thread-2 - document 2060thread-4 - document 4059thread-3 - document 3060thread-0 - document 62thread-1 - document 1058
#
#
#
#
# thread-2 - document 2061thread-4 - document 4060 thread-0 - document 63thread-1 - document 1059
#
# thread-3 - document 3061
#
# thread-2 - document 2062thread-4 - document 4061
#
#
#  thread-0 - document 64thread-1 - document 1060thread-2 - document 2063 thread-3 - document 3062
#
#
# thread-4 - document 4062
#  thread-1 - document 1061
# thread-3 - document 3063thread-0 - document 65
# thread-2 - document 2064thread-4 - document 4063
#
# thread-1 - document 1062
#
# thread-3 - document 3064thread-0 - document 66
# thread-2 - document 2065thread-4 - document 4064
#
# thread-1 - document 1063
#
# thread-3 - document 3065thread-0 - document 67
#  thread-4 - document 4065
#
# thread-1 - document 1064thread-2 - document 2066
# thread-3 - document 3066thread-0 - document 68
#
#
#
# thread-1 - document 1065thread-2 - document 2067thread-4 - document 4066thread-3 - document 3067thread-0 - document 69
#
#
#
#
# thread-1 - document 1066 thread-4 - document 4067thread-3 - document 3068thread-0 - document 70
# thread-2 - document 2068
#
#
#
# thread-4 - document 4068thread-3 - document 3069thread-0 - document 71thread-1 - document 1067
#
#
#
# thread-2 - document 2069thread-4 - document 4069thread-3 - document 3070thread-0 - document 72thread-1 - document 1068
#
#
#
#
# thread-2 - document 2070thread-4 - document 4070thread-3 - document 3071thread-0 - document 73thread-1 - document 1069
#
#
#
#
# thread-2 - document 2071thread-4 - document 4071thread-3 - document 3072thread-0 - document 74
#
#
#
# thread-1 - document 1070thread-2 - document 2072thread-4 - document 4072thread-3 - document 3073thread-0 - document 75
#
#
#
#
# thread-1 - document 1071thread-2 - document 2073 thread-3 - document 3074thread-0 - document 76
# thread-4 - document 4073
#
# thread-1 - document 1072
#
# thread-3 - document 3075thread-0 - document 77
# thread-2 - document 2074thread-4 - document 4074
#
# thread-1 - document 1073
#
# thread-3 - document 3076thread-0 - document 78
# thread-2 - document 2075
#
# thread-1 - document 1074
# thread-4 - document 4075 thread-0 - document 79
# thread-2 - document 2076
# thread-3 - document 3077
# thread-1 - document 1075
# thread-4 - document 4076
# thread-0 - document 80
# thread-2 - document 2077
# thread-3 - document 3078
# thread-1 - document 1076
# thread-4 - document 4077
# thread-0 - document 81
# thread-2 - document 2078
# thread-3 - document 3079
# thread-1 - document 1077
# thread-4 - document 4078
# thread-0 - document 82
#
# thread-3 - document 3080
# thread-1 - document 1078thread-2 - document 2079
# thread-0 - document 83
#
# thread-4 - document 4079thread-3 - document 3081
# thread-1 - document 1079thread-2 - document 2080
#
# thread-0 - document 84
#
# thread-4 - document 4080thread-3 - document 3082
#
#
# thread-0 - document 85thread-1 - document 1080thread-2 - document 2081thread-4 - document 4081thread-3 - document 3083
#
#
#
#
# thread-0 - document 86thread-1 - document 1081thread-2 - document 2082thread-4 - document 4082thread-3 - document 3084
#
#
#
#
# thread-0 - document 87 thread-2 - document 2083thread-4 - document 4083thread-3 - document 3085
# thread-1 - document 1082
#
#
# thread-0 - document 88
#  thread-4 - document 4084thread-3 - document 3086
#  thread-2 - document 2084
#
# thread-0 - document 89thread-1 - document 1083
# thread-4 - document 4085thread-3 - document 3087
#
# thread-2 - document 2085
#
# thread-0 - document 90thread-1 - document 1084
# thread-4 - document 4086
#
# thread-2 - document 2086
# thread-3 - document 3088thread-0 - document 91thread-1 - document 1085
# thread-4 - document 4087
#
#
# thread-2 - document 2087
# thread-3 - document 3089thread-0 - document 92thread-1 - document 1086
# thread-4 - document 4088
#
#
# thread-2 - document 2088
# thread-3 - document 3090 thread-1 - document 1087
# thread-4 - document 4089
# thread-0 - document 93
# thread-2 - document 2089
# thread-3 - document 3091
# thread-1 - document 1088
# thread-4 - document 4090
# thread-0 - document 94
# thread-2 - document 2090
# thread-3 - document 3092
# thread-1 - document 1089
# thread-4 - document 4091
# thread-0 - document 95
# thread-2 - document 2091
# thread-3 - document 3093
# thread-1 - document 1090
# thread-4 - document 4092
# thread-0 - document 96
#
# thread-3 - document 3094
# thread-1 - document 1091thread-2 - document 2092thread-4 - document 4093
#
#
#
# thread-3 - document 3095thread-0 - document 97thread-1 - document 1092thread-2 - document 2093
#
#
#
# thread-4 - document 4094thread-3 - document 3096 thread-1 - document 1093thread-2 - document 2094
#
# thread-0 - document 98
#
# thread-4 - document 4095
# thread-1 - document 1094thread-2 - document 2095
# thread-3 - document 3097
#
# thread-4 - document 4096
# thread-0 - document 99thread-1 - document 1095
# thread-3 - document 3098
#
# thread-2 - document 2096thread-4 - document 4097
# thread-0 - document 100thread-1 - document 1096
#
#
#
# thread-2 - document 2097thread-4 - document 4098thread-3 - document 3099thread-0 - document 101thread-1 - document 1097
#
#
#
#
# thread-2 - document 2098thread-4 - document 4099thread-3 - document 3100thread-0 - document 102thread-1 - document 1098
#
#
#
#
# thread-2 - document 2099thread-4 - document 4100 thread-0 - document 103thread-1 - document 1099
#
# thread-3 - document 3101
#
# thread-2 - document 2100thread-4 - document 4101
#  thread-1 - document 1100
#
# thread-3 - document 3102thread-0 - document 104
# thread-2 - document 2101thread-4 - document 4102
#
# thread-1 - document 1101
#
# thread-3 - document 3103thread-0 - document 105
# thread-2 - document 2102
#
# thread-1 - document 1102
# thread-4 - document 4103thread-3 - document 3104thread-0 - document 106
#
#
#
# thread-1 - document 1103thread-2 - document 2103thread-4 - document 4104thread-3 - document 3105thread-0 - document 107
#
#
#
#
# thread-1 - document 1104 thread-4 - document 4105thread-3 - document 3106thread-0 - document 108
# thread-2 - document 2104
#
#
# thread-1 - document 1105
# thread-4 - document 4106thread-3 - document 3107thread-0 - document 109
#
#
#
# thread-1 - document 1106thread-2 - document 2105 thread-3 - document 3108thread-0 - document 110
#
# thread-4 - document 4107
#
# thread-1 - document 1107thread-2 - document 2106
# thread-3 - document 3109
#
# thread-4 - document 4108
# thread-0 - document 111thread-1 - document 1108thread-2 - document 2107
# thread-3 - document 3110
#
#
# thread-4 - document 4109
# thread-0 - document 112thread-1 - document 1109thread-2 - document 2108
# thread-3 - document 3111
#
#
# thread-4 - document 4110
# thread-0 - document 113 thread-2 - document 2109
# thread-3 - document 3112
# thread-1 - document 1110
# thread-4 - document 4111
# thread-0 - document 114
# thread-2 - document 2110
# thread-3 - document 3113
#
#
# thread-0 - document 115thread-1 - document 1111thread-2 - document 2111thread-4 - document 4112thread-3 - document 3114
#
#
#
#
# thread-0 - document 116thread-1 - document 1112 thread-4 - document 4113thread-3 - document 3115
#
# thread-2 - document 2112
#
# thread-0 - document 117thread-1 - document 1113
# thread-4 - document 4114thread-3 - document 3116
#
# thread-2 - document 2113
#
# thread-0 - document 118thread-1 - document 1114
# thread-4 - document 4115thread-3 - document 3117
#
# thread-2 - document 2114
#
# thread-0 - document 119thread-1 - document 1115
# thread-4 - document 4116
#
# thread-2 - document 2115
# thread-3 - document 3118thread-0 - document 120thread-1 - document 1116
#
#
#
# thread-2 - document 2116thread-4 - document 4117thread-3 - document 3119thread-0 - document 121thread-1 - document 1117
#
#
#
#
# thread-2 - document 2117thread-4 - document 4118thread-3 - document 3120thread-0 - document 122thread-1 - document 1118
#
#
#
#
# thread-2 - document 2118thread-4 - document 4119thread-3 - document 3121thread-0 - document 123thread-1 - document 1119
#
#
#
#
# thread-2 - document 2119thread-4 - document 4120thread-3 - document 3122thread-0 - document 124thread-1 - document 1120
#
#
#
#
# thread-2 - document 2120thread-4 - document 4121thread-3 - document 3123thread-0 - document 125thread-1 - document 1121
#
#
#
#
# thread-2 - document 2121thread-4 - document 4122thread-3 - document 3124thread-0 - document 126thread-1 - document 1122
#
#
#
#
# thread-2 - document 2122thread-4 - document 4123thread-3 - document 3125thread-0 - document 127
#
#
#
# thread-1 - document 1123 thread-4 - document 4124thread-3 - document 3126thread-0 - document 128
# thread-2 - document 2123
#
#
# thread-1 - document 1124
# thread-4 - document 4125thread-3 - document 3127thread-0 - document 129
# thread-2 - document 2124
#
#
#
# thread-4 - document 4126thread-3 - document 3128thread-0 - document 130thread-1 - document 1125thread-2 - document 2125
#
#
#
#
# thread-4 - document 4127thread-3 - document 3129thread-0 - document 131thread-1 - document 1126thread-2 - document 2126
#
#
#
#
# thread-4 - document 4128thread-3 - document 3130thread-0 - document 132thread-1 - document 1127
#
#
#
# thread-2 - document 2127thread-4 - document 4129thread-3 - document 3131thread-0 - document 133
#
#
#
# thread-1 - document 1128thread-2 - document 2128thread-4 - document 4130thread-3 - document 3132thread-0 - document 134
#
#
#
#
# thread-1 - document 1129thread-2 - document 2129thread-4 - document 4131thread-3 - document 3133thread-0 - document 135
#
#
#
#
# thread-1 - document 1130 thread-4 - document 4132thread-3 - document 3134thread-0 - document 136
# thread-2 - document 2130
#
#
# thread-1 - document 1131
# thread-4 - document 4133 thread-0 - document 137
#
# thread-3 - document 3135
# thread-1 - document 1132thread-2 - document 2131thread-4 - document 4134
# thread-0 - document 138
#
#
# thread-3 - document 3136
#  thread-2 - document 2132
# thread-0 - document 139thread-1 - document 1133
# thread-4 - document 4135thread-3 - document 3137
#
# thread-2 - document 2133
#
# thread-0 - document 140thread-1 - document 1134
#  thread-3 - document 3138
#
# thread-2 - document 2134thread-4 - document 4136
# thread-0 - document 141
#
# thread-3 - document 3139
# thread-1 - document 1135 thread-4 - document 4137
#
# thread-2 - document 2135
# thread-3 - document 3140thread-0 - document 142thread-1 - document 1136
# thread-4 - document 4138
#
#
#
# thread-3 - document 3141thread-0 - document 143thread-1 - document 1137thread-2 - document 2136thread-4 - document 4139
#
#
#
#
# thread-3 - document 3142thread-0 - document 144thread-2 - document 2137thread-4 - document 4140
#
# thread-1 - document 1138
#
# thread-3 - document 3143thread-0 - document 145
# thread-2 - document 2138thread-4 - document 4141
#
# thread-1 - document 1139
#
# thread-3 - document 3144thread-0 - document 146
# thread-2 - document 2139thread-4 - document 4142
#
# thread-1 - document 1140
#
# thread-3 - document 3145thread-0 - document 147
# thread-2 - document 2140thread-4 - document 4143
#
# thread-1 - document 1141
#
#  thread-0 - document 148
# thread-2 - document 2141thread-4 - document 4144thread-3 - document 3146
# thread-1 - document 1142
#
#
# thread-0 - document 149
# thread-2 - document 2142thread-4 - document 4145thread-3 - document 3147
# thread-1 - document 1143
#
#
# thread-0 - document 150
# thread-2 - document 2143thread-4 - document 4146thread-3 - document 3148
# thread-1 - document 1144
#
#
# thread-0 - document 151
#  thread-4 - document 4147thread-3 - document 3149
# thread-1 - document 1145thread-2 - document 2144
#
# thread-0 - document 152
#
# thread-4 - document 4148thread-3 - document 3150
# thread-1 - document 1146thread-2 - document 2145
#
# thread-0 - document 153
#
# thread-4 - document 4149thread-3 - document 3151
# thread-1 - document 1147
#
# thread-0 - document 154
# thread-2 - document 2146thread-4 - document 4150thread-3 - document 3152
# thread-1 - document 1148
#
#
#
# thread-2 - document 2147thread-4 - document 4151thread-3 - document 3153thread-0 - document 155thread-1 - document 1149
#
#
#
#
#  thread-4 - document 4152thread-3 - document 3154thread-0 - document 156thread-1 - document 1150thread-2 - document 2148
#
#
#
#
# thread-4 - document 4153thread-3 - document 3155thread-0 - document 157thread-1 - document 1151
#
#
#
# thread-2 - document 2149thread-4 - document 4154thread-3 - document 3156thread-0 - document 158thread-1 - document 1152
#
#
#
#
# thread-2 - document 2150thread-4 - document 4155thread-3 - document 3157thread-0 - document 159thread-1 - document 1153
#
#
#
#
# thread-2 - document 2151thread-4 - document 4156 thread-0 - document 160thread-1 - document 1154
#
# thread-3 - document 3158
#
# thread-2 - document 2152
# thread-0 - document 161thread-1 - document 1155
# thread-4 - document 4157thread-3 - document 3159
#
# thread-2 - document 2153
#
# thread-0 - document 162thread-1 - document 1156
# thread-4 - document 4158thread-3 - document 3160
#
# thread-2 - document 2154
#
# thread-0 - document 163thread-1 - document 1157
# thread-4 - document 4159thread-3 - document 3161
#
# thread-2 - document 2155
#
# thread-0 - document 164thread-1 - document 1158
# thread-4 - document 4160thread-3 - document 3162
#
# thread-2 - document 2156
#
# thread-0 - document 165thread-1 - document 1159
# thread-4 - document 4161thread-3 - document 3163
#
# thread-2 - document 2157
#
# thread-0 - document 166
# thread-4 - document 4162thread-3 - document 3164
# thread-1 - document 1160thread-2 - document 2158
#
# thread-0 - document 167
#
# thread-4 - document 4163thread-3 - document 3165
#  thread-2 - document 2159
#
# thread-0 - document 168thread-1 - document 1161
# thread-4 - document 4164
#
#
# thread-3 - document 3166thread-0 - document 169 thread-2 - document 2160thread-4 - document 4165
#
# thread-1 - document 1162
#
# thread-3 - document 3167thread-0 - document 170
# thread-2 - document 2161thread-4 - document 4166
#
# thread-1 - document 1163
#
# thread-3 - document 3168thread-0 - document 171
# thread-2 - document 2162thread-4 - document 4167
#
#
#
# thread-3 - document 3169 thread-1 - document 1164thread-2 - document 2163thread-4 - document 4168
# thread-0 - document 172
#
#
#
# thread-1 - document 1165thread-2 - document 2164thread-4 - document 4169thread-3 - document 3170
#
#
#
# thread-0 - document 173thread-1 - document 1166thread-2 - document 2165thread-4 - document 4170thread-3 - document 3171
#
#
#
#
# thread-0 - document 174thread-1 - document 1167thread-2 - document 2166thread-4 - document 4171thread-3 - document 3172
#
#
#
#
# thread-0 - document 175thread-1 - document 1168thread-2 - document 2167thread-4 - document 4172
#
#
#
# thread-3 - document 3173thread-0 - document 176thread-1 - document 1169thread-2 - document 2168thread-4 - document 4173
#
#
#
#
# thread-3 - document 3174thread-0 - document 177thread-1 - document 1170thread-2 - document 2169thread-4 - document 4174
#
#
#
#
#  thread-0 - document 178thread-1 - document 1171thread-2 - document 2170thread-4 - document 4175thread-3 - document 3175
#
#
#
#
# thread-0 - document 179thread-1 - document 1172thread-2 - document 2171thread-4 - document 4176thread-3 - document 3176
#
#
#
#
# thread-0 - document 180thread-1 - document 1173thread-2 - document 2172thread-4 - document 4177thread-3 - document 3177
#
#
#
#
#  thread-1 - document 1174thread-2 - document 2173thread-4 - document 4178 thread-0 - document 181
#
#
# thread-3 - document 3178
# thread-1 - document 1175thread-2 - document 2174thread-4 - document 4179
# thread-0 - document 182
#
#
# thread-3 - document 3179
# thread-1 - document 1176thread-2 - document 2175
# thread-0 - document 183
#
# thread-4 - document 4180thread-3 - document 3180
# thread-1 - document 1177thread-2 - document 2176
#
# thread-0 - document 184
#
# thread-4 - document 4181thread-3 - document 3181
# thread-1 - document 1178thread-2 - document 2177
#
# thread-0 - document 185
#
# thread-4 - document 4182thread-3 - document 3182
# thread-1 - document 1179thread-2 - document 2178
#
# thread-0 - document 186
#
# thread-4 - document 4183thread-3 - document 3183
# thread-1 - document 1180
#
#
# thread-2 - document 2179thread-4 - document 4184thread-3 - document 3184thread-0 - document 187thread-1 - document 1181
#
#
#
#
# thread-2 - document 2180thread-4 - document 4185thread-3 - document 3185thread-0 - document 188
#
#
#
# thread-1 - document 1182 thread-4 - document 4186thread-3 - document 3186thread-0 - document 189
# thread-2 - document 2181
#
#
# thread-1 - document 1183
# thread-4 - document 4187thread-3 - document 3187thread-0 - document 190
# thread-2 - document 2182
#
#
# thread-1 - document 1184
# thread-4 - document 4188thread-3 - document 3188thread-0 - document 191
# thread-2 - document 2183
#
#
# thread-1 - document 1185
# thread-4 - document 4189thread-3 - document 3189thread-0 - document 192
# thread-2 - document 2184
#
#
# thread-1 - document 1186
# thread-4 - document 4190thread-3 - document 3190thread-0 - document 193
# thread-2 - document 2185
#
#
# thread-1 - document 1187
# thread-4 - document 4191thread-3 - document 3191thread-0 - document 194
# thread-2 - document 2186
#
#
#
# thread-4 - document 4192thread-3 - document 3192thread-0 - document 195thread-1 - document 1188thread-2 - document 2187
#
#
#
#
# thread-4 - document 4193thread-3 - document 3193thread-0 - document 196thread-1 - document 1189
#
#
#
# thread-2 - document 2188 thread-3 - document 3194thread-0 - document 197
# thread-4 - document 4194
#
# thread-1 - document 1190thread-2 - document 2189
# thread-3 - document 3195thread-0 - document 198
#
# thread-4 - document 4195
#
# thread-1 - document 1191thread-2 - document 2190
# thread-3 - document 3196thread-0 - document 199
#
# thread-4 - document 4196
#
# thread-1 - document 1192
# thread-3 - document 3197
# thread-2 - document 2191thread-4 - document 4197
# thread-0 - document 200thread-1 - document 1193
#
# thread-3 - document 3198
#
#  thread-4 - document 4198
# thread-0 - document 201thread-1 - document 1194thread-2 - document 2192
# thread-3 - document 3199
#
#
#
# thread-0 - document 202thread-1 - document 1195thread-2 - document 2193thread-4 - document 4199
#
#
#
# thread-3 - document 3200thread-0 - document 203thread-1 - document 1196 thread-4 - document 4200
#
#
# thread-2 - document 2194
#  thread-0 - document 204thread-1 - document 1197
# thread-4 - document 4201thread-3 - document 3201
#
# thread-2 - document 2195
#
# thread-0 - document 205thread-1 - document 1198
# thread-4 - document 4202thread-3 - document 3202
#
# thread-2 - document 2196
#
# thread-0 - document 206thread-1 - document 1199
#  thread-3 - document 3203
#
#  thread-4 - document 4203
# thread-0 - document 207thread-1 - document 1200thread-2 - document 2197
# thread-3 - document 3204
#
#
#
# thread-0 - document 208 thread-2 - document 2198thread-4 - document 4204thread-3 - document 3205
# thread-1 - document 1201
#
#
# thread-0 - document 209
# thread-2 - document 2199 thread-3 - document 3206
# thread-1 - document 1202
# thread-4 - document 4205
# thread-0 - document 210
# thread-2 - document 2200
# thread-3 - document 3207
# thread-1 - document 1203
# thread-4 - document 4206
# thread-0 - document 211
# thread-2 - document 2201
# thread-3 - document 3208
# thread-1 - document 1204
# thread-4 - document 4207
# thread-0 - document 212
# thread-2 - document 2202
#
# thread-1 - document 1205
#  thread-3 - document 3209thread-0 - document 213
# thread-2 - document 2203thread-4 - document 4208
#
# thread-1 - document 1206
#
# thread-3 - document 3210thread-0 - document 214
# thread-2 - document 2204thread-4 - document 4209
#
# thread-1 - document 1207
#
# thread-3 - document 3211thread-0 - document 215
# thread-2 - document 2205thread-4 - document 4210
#
# thread-1 - document 1208
#
# thread-3 - document 3212thread-0 - document 216
# thread-2 - document 2206thread-4 - document 4211
#
# thread-1 - document 1209
#
# thread-3 - document 3213thread-0 - document 217
# thread-2 - document 2207thread-4 - document 4212
#
# thread-1 - document 1210
#
# thread-3 - document 3214
# thread-2 - document 2208thread-4 - document 4213
# thread-0 - document 218thread-1 - document 1211
#
# thread-3 - document 3215
#
# thread-2 - document 2209thread-4 - document 4214
# thread-0 - document 219thread-1 - document 1212
#
#
#
#  thread-4 - document 4215thread-3 - document 3216thread-0 - document 220thread-1 - document 1213thread-2 - document 2210
#
#
#
#
# thread-4 - document 4216  thread-1 - document 1214thread-2 - document 2211
# thread-3 - document 3217thread-0 - document 221
#
# thread-4 - document 4217
#
# thread-1 - document 1215thread-2 - document 2212
# thread-3 - document 3218thread-0 - document 222
#
# thread-4 - document 4218
#
# thread-1 - document 1216thread-2 - document 2213
# thread-3 - document 3219thread-0 - document 223
#
# thread-4 - document 4219
#
#  thread-2 - document 2214
# thread-3 - document 3220thread-0 - document 224thread-1 - document 1217
# thread-4 - document 4220
#
#
# thread-2 - document 2215
# thread-3 - document 3221thread-0 - document 225thread-1 - document 1218
#
#
#
# thread-2 - document 2216thread-4 - document 4221thread-3 - document 3222thread-0 - document 226thread-1 - document 1219
#
#
#
#
# thread-2 - document 2217thread-4 - document 4222thread-3 - document 3223thread-0 - document 227thread-1 - document 1220
#
#
#
#
#  thread-4 - document 4223thread-3 - document 3224 thread-1 - document 1221thread-2 - document 2218
#
# thread-0 - document 228
#
# thread-4 - document 4224thread-3 - document 3225
# thread-1 - document 1222
#
# thread-0 - document 229
# thread-2 - document 2219thread-4 - document 4225thread-3 - document 3226
# thread-1 - document 1223
#
#
# thread-0 - document 230
# thread-2 - document 2220thread-4 - document 4226thread-3 - document 3227
# thread-1 - document 1224
#
#
# thread-0 - document 231
#  thread-4 - document 4227
# thread-1 - document 1225thread-2 - document 2221
# thread-3 - document 3228
#
# thread-4 - document 4228
# thread-0 - document 232 thread-2 - document 2222
# thread-3 - document 3229
# thread-1 - document 1226
# thread-4 - document 4229
# thread-0 - document 233
# thread-2 - document 2223
# thread-3 - document 3230
# thread-1 - document 1227
# thread-4 - document 4230
# thread-0 - document 234
#
# thread-3 - document 3231
# thread-1 - document 1228thread-2 - document 2224thread-4 - document 4231
# thread-0 - document 235
#
#
# thread-3 - document 3232
# thread-1 - document 1229thread-2 - document 2225thread-4 - document 4232
#
#
#
# thread-3 - document 3233thread-0 - document 236thread-1 - document 1230thread-2 - document 2226thread-4 - document 4233
#
#
#
#
#  thread-0 - document 237thread-1 - document 1231thread-2 - document 2227thread-4 - document 4234thread-3 - document 3234
#
#
#
#
# thread-0 - document 238thread-1 - document 1232thread-2 - document 2228thread-4 - document 4235thread-3 - document 3235
#
#
#
#
# thread-0 - document 239thread-1 - document 1233 thread-4 - document 4236thread-3 - document 3236
#
# thread-2 - document 2229
#
# thread-0 - document 240
# thread-4 - document 4237thread-3 - document 3237
# thread-1 - document 1234thread-2 - document 2230
#
# thread-0 - document 241
#
#  thread-3 - document 3238
#  thread-2 - document 2231thread-4 - document 4238
# thread-0 - document 242thread-1 - document 1235
#
# thread-3 - document 3239
#
# thread-2 - document 2232thread-4 - document 4239
# thread-0 - document 243
#
# thread-3 - document 3240
# thread-1 - document 1236thread-2 - document 2233
# thread-0 - document 244
#
# thread-4 - document 4240thread-3 - document 3241thread-1 - document 1237thread-2 - document 2234
#
#
#
#
#  thread-3 - document 3242thread-0 - document 245thread-1 - document 1238thread-2 - document 2235thread-4 - document 4241
#
#
#
#
# thread-3 - document 3243thread-0 - document 246thread-1 - document 1239thread-2 - document 2236
#
#
#
# thread-4 - document 4242thread-3 - document 3244 thread-1 - document 1240thread-2 - document 2237
#
# thread-0 - document 247
#
#  thread-3 - document 3245
# thread-1 - document 1241thread-2 - document 2238thread-4 - document 4243
# thread-0 - document 248
#
#
# thread-3 - document 3246
# thread-1 - document 1242thread-2 - document 2239thread-4 - document 4244
# thread-0 - document 249
#
#
# thread-3 - document 3247
# thread-1 - document 1243thread-2 - document 2240thread-4 - document 4245
# thread-0 - document 250
#
#
#
#    thread-3 - document 3248thread-0 - document 251thread-1 - document 1244thread-2 - document 2241thread-4 - document 4246
#
#
#
#
#  thread-0 - document 252thread-1 - document 1245thread-2 - document 2242thread-4 - document 4247thread-3 - document 3249
#
#
#
#
# thread-0 - document 253thread-1 - document 1246thread-2 - document 2243thread-4 - document 4248thread-3 - document 3250
#
#
#
#
# thread-0 - document 254 thread-2 - document 2244thread-4 - document 4249thread-3 - document 3251
# thread-1 - document 1247
#
#
# thread-0 - document 255
# thread-2 - document 2245thread-4 - document 4250thread-3 - document 3252
# thread-1 - document 1248
#
#
# thread-0 - document 256
#   thread-3 - document 3253
# thread-1 - document 1249thread-2 - document 2246thread-4 - document 4251
# thread-0 - document 257
#
#
# thread-3 - document 3254
# thread-1 - document 1250thread-2 - document 2247thread-4 - document 4252
# thread-0 - document 258
#
#
# thread-3 - document 3255
# thread-1 - document 1251thread-2 - document 2248thread-4 - document 4253
# thread-0 - document 259
#
#
#
# thread-1 - document 1252 thread-4 - document 4254thread-3 - document 3256thread-0 - document 260
# thread-2 - document 2249
#
#
# thread-1 - document 1253
# thread-4 - document 4255thread-3 - document 3257thread-0 - document 261
# thread-2 - document 2250
#
#
# thread-1 - document 1254
# thread-4 - document 4256thread-3 - document 3258thread-0 - document 262
# thread-2 - document 2251
#
#
# thread-1 - document 1255
# thread-4 - document 4257thread-3 - document 3259thread-0 - document 263
# thread-2 - document 2252
#
#
# thread-1 - document 1256
# thread-4 - document 4258thread-3 - document 3260
# thread-2 - document 2253
#
# thread-0 - document 264thread-1 - document 1257
# thread-4 - document 4259
#
# thread-2 - document 2254
# thread-3 - document 3261 thread-1 - document 1258
# thread-4 - document 4260
# thread-0 - document 265
# thread-2 - document 2255
# thread-3 - document 3262
# thread-1 - document 1259
# thread-4 - document 4261
# thread-0 - document 266
# thread-2 - document 2256
# thread-3 - document 3263
# thread-1 - document 1260
# thread-4 - document 4262
# thread-0 - document 267
#
# thread-3 - document 3264
# thread-1 - document 1261thread-2 - document 2257thread-4 - document 4263
# thread-0 - document 268
#
#
#
# thread-1 - document 1262thread-2 - document 2258thread-4 - document 4264thread-3 - document 3265thread-0 - document 269
#
#
#
#
# thread-1 - document 1263thread-2 - document 2259thread-4 - document 4265thread-3 - document 3266thread-0 - document 270
#
#
#
#
# thread-1 - document 1264 thread-4 - document 4266thread-3 - document 3267thread-0 - document 271
# thread-2 - document 2260
#
#
# thread-1 - document 1265
# thread-4 - document 4267thread-3 - document 3268thread-0 - document 272
# thread-2 - document 2261
#
#
# thread-1 - document 1266
# thread-4 - document 4268thread-3 - document 3269thread-0 - document 273
# thread-2 - document 2262
#
#
# thread-1 - document 1267
# thread-4 - document 4269thread-3 - document 3270
# thread-2 - document 2263
#
# thread-0 - document 274thread-1 - document 1268
#  thread-3 - document 3271
#
# thread-2 - document 2264thread-4 - document 4270
# thread-0 - document 275thread-1 - document 1269
#
# thread-3 - document 3272
#
#  thread-4 - document 4271
# thread-0 - document 276thread-1 - document 1270thread-2 - document 2265
# thread-3 - document 3273
#
#
# thread-4 - document 4272
# thread-0 - document 277 thread-2 - document 2266
# thread-3 - document 3274
# thread-1 - document 1271
# thread-4 - document 4273
# thread-0 - document 278
# thread-2 - document 2267
#
#
#  thread-3 - document 3275 thread-1 - document 1272thread-2 - document 2268thread-4 - document 4274
# thread-0 - document 279
#
#
#
# thread-1 - document 1273thread-2 - document 2269thread-4 - document 4275thread-3 - document 3276
#
#
#
# thread-0 - document 280 thread-2 - document 2270thread-4 - document 4276thread-3 - document 3277
# thread-1 - document 1274
#
#
# thread-0 - document 281
# thread-2 - document 2271
#
# thread-4 - document 4277thread-3 - document 3278thread-0 - document 282thread-1 - document 1275thread-2 - document 2272
#
#
#
#
# thread-4 - document 4278thread-3 - document 3279thread-0 - document 283thread-1 - document 1276thread-2 - document 2273
#
#
#
#
# thread-4 - document 4279thread-3 - document 3280 thread-1 - document 1277thread-2 - document 2274
#
# thread-0 - document 284
#
# thread-4 - document 4280thread-3 - document 3281
# thread-1 - document 1278thread-2 - document 2275
#
#
#
# thread-4 - document 4281thread-3 - document 3282thread-0 - document 285thread-1 - document 1279thread-2 - document 2276
#
#
#
#
# thread-4 - document 4282thread-3 - document 3283thread-0 - document 286thread-1 - document 1280thread-2 - document 2277
#
#
#
#
#  thread-3 - document 3284thread-0 - document 287thread-1 - document 1281thread-2 - document 2278thread-4 - document 4283
#
#
#
#
# thread-3 - document 3285 thread-1 - document 1282thread-2 - document 2279thread-4 - document 4284
# thread-0 - document 288
#
#
# thread-3 - document 3286
# thread-1 - document 1283 thread-4 - document 4285
# thread-0 - document 289
# thread-2 - document 2280
# thread-3 - document 3287
# thread-1 - document 1284
# thread-4 - document 4286
# thread-0 - document 290
# thread-2 - document 2281
# thread-3 - document 3288
# thread-1 - document 1285
# thread-4 - document 4287
# thread-0 - document 291
# thread-2 - document 2282
# thread-3 - document 3289
# thread-1 - document 1286
# thread-4 - document 4288
# thread-0 - document 292
# thread-2 - document 2283
#
#
# thread-4 - document 4289thread-3 - document 3290thread-0 - document 293thread-1 - document 1287thread-2 - document 2284
#
#
#
#
# thread-4 - document 4290thread-3 - document 3291  thread-2 - document 2285
#
# thread-0 - document 294thread-1 - document 1288
# thread-4 - document 4291thread-3 - document 3292
#
# thread-2 - document 2286
#
#  thread-1 - document 1289
#  thread-3 - document 3293thread-0 - document 295
# thread-2 - document 2287thread-4 - document 4292
#
#
#
# thread-3 - document 3294thread-0 - document 296thread-1 - document 1290 thread-4 - document 4293
#
#
# thread-2 - document 2288
# thread-3 - document 3295thread-0 - document 297thread-1 - document 1291
# thread-4 - document 4294
#
#
# thread-2 - document 2289
#  thread-0 - document 298thread-1 - document 1292
# thread-4 - document 4295thread-3 - document 3296
#
#
#
# thread-0 - document 299thread-1 - document 1293thread-2 - document 2290thread-4 - document 4296thread-3 - document 3297
#
#
#
#
# thread-0 - document 300thread-1 - document 1294thread-2 - document 2291thread-4 - document 4297thread-3 - document 3298
#
#
#
#
# thread-0 - document 301thread-1 - document 1295thread-2 - document 2292thread-4 - document 4298
#
#
#
# thread-3 - document 3299thread-0 - document 302thread-1 - document 1296thread-2 - document 2293thread-4 - document 4299
#
#
#
#
#  thread-0 - document 303thread-1 - document 1297thread-2 - document 2294thread-4 - document 4300thread-3 - document 3300
#
#
#
#
# thread-0 - document 304thread-1 - document 1298thread-2 - document 2295thread-4 - document 4301thread-3 - document 3301
#
#
#
#
#  thread-1 - document 1299thread-2 - document 2296thread-4 - document 4302thread-3 - document 3302thread-0 - document 305
#
#
#
#
# thread-1 - document 1300thread-2 - document 2297thread-4 - document 4303thread-3 - document 3303thread-0 - document 306
#
#
#
#
# thread-1 - document 1301thread-2 - document 2298thread-4 - document 4304 thread-0 - document 307
#
#
# thread-3 - document 3304
# thread-1 - document 1302thread-2 - document 2299thread-4 - document 4305
#
#
#
#  thread-0 - document 308thread-1 - document 1303thread-2 - document 2300thread-4 - document 4306thread-3 - document 3305
#
#
#
#
# thread-0 - document 309 thread-2 - document 2301thread-4 - document 4307
# thread-1 - document 1304
#
# thread-3 - document 3306thread-0 - document 310
#  thread-4 - document 4308
#
# thread-1 - document 1305thread-2 - document 2302
# thread-3 - document 3307thread-0 - document 311
#
# thread-4 - document 4309
#
# thread-1 - document 1306thread-2 - document 2303
# thread-3 - document 3308thread-0 - document 312
#
# thread-4 - document 4310
#
# thread-1 - document 1307thread-2 - document 2304
# thread-3 - document 3309thread-0 - document 313
#
# thread-4 - document 4311
#
# thread-1 - document 1308thread-2 - document 2305
#  thread-0 - document 314
#
# thread-4 - document 4312thread-3 - document 3310
# thread-1 - document 1309thread-2 - document 2306
#
# thread-0 - document 315
#
# thread-4 - document 4313thread-3 - document 3311
# thread-1 - document 1310thread-2 - document 2307
#
# thread-0 - document 316
#
# thread-4 - document 4314
#  thread-2 - document 2308
# thread-3 - document 3312thread-0 - document 317thread-1 - document 1311
# thread-4 - document 4315
#
#
#
# thread-3 - document 3313thread-0 - document 318 thread-2 - document 2309thread-4 - document 4316
#
# thread-1 - document 1312
#
# thread-3 - document 3314thread-0 - document 319
# thread-2 - document 2310thread-4 - document 4317
#
# thread-1 - document 1313
#
# thread-3 - document 3315thread-0 - document 320
# thread-2 - document 2311thread-4 - document 4318
#
#
#
# thread-3 - document 3316thread-0 - document 321thread-1 - document 1314thread-2 - document 2312
#
#
#
# thread-4 - document 4319thread-3 - document 3317thread-0 - document 322thread-1 - document 1315thread-2 - document 2313
#
#
#
#
# thread-4 - document 4320thread-3 - document 3318thread-0 - document 323thread-1 - document 1316thread-2 - document 2314
#
#
#
#
# thread-4 - document 4321 thread-0 - document 324thread-1 - document 1317thread-2 - document 2315
# thread-3 - document 3319
#
#
# thread-4 - document 4322
# thread-0 - document 325 thread-2 - document 2316
# thread-3 - document 3320
# thread-1 - document 1318
# thread-4 - document 4323
#
# thread-2 - document 2317
# thread-3 - document 3321thread-0 - document 326thread-1 - document 1319
# thread-4 - document 4324
#
#
# thread-2 - document 2318
#  thread-0 - document 327
# thread-4 - document 4325thread-3 - document 3322
# thread-1 - document 1320thread-2 - document 2319
#
#
#
# thread-4 - document 4326thread-3 - document 3323thread-0 - document 328 thread-2 - document 2320
#
#
# thread-1 - document 1321
# thread-4 - document 4327thread-3 - document 3324thread-0 - document 329
# thread-2 - document 2321
#
#
#
# thread-4 - document 4328 thread-0 - document 330thread-1 - document 1322thread-2 - document 2322
# thread-3 - document 3325
#
#
# thread-4 - document 4329
# thread-0 - document 331thread-1 - document 1323thread-2 - document 2323
# thread-3 - document 3326
#
#
# thread-4 - document 4330
# thread-0 - document 332thread-1 - document 1324thread-2 - document 2324
# thread-3 - document 3327
#
#
# thread-4 - document 4331
# thread-0 - document 333thread-1 - document 1325thread-2 - document 2325
# thread-3 - document 3328
#
#
# thread-4 - document 4332
# thread-0 - document 334thread-1 - document 1326thread-2 - document 2326
# thread-3 - document 3329
#
#
# thread-4 - document 4333
# thread-0 - document 335thread-1 - document 1327thread-2 - document 2327
# thread-3 - document 3330
#
#
# thread-4 - document 4334
# thread-0 - document 336thread-1 - document 1328thread-2 - document 2328
# thread-3 - document 3331
#
#
# thread-4 - document 4335
#  thread-1 - document 1329thread-2 - document 2329
#  thread-0 - document 337
#
#  thread-3 - document 3332
#   thread-4 - document 4336
#  thread-1 - document 1330thread-2 - document 2330
# thread-3 - document 3333thread-0 - document 338
#
# thread-4 - document 4337
#
#
# thread-3 - document 3334thread-0 - document 339thread-1 - document 1331thread-2 - document 2331thread-4 - document 4338
#
#
#
#
# thread-3 - document 3335 thread-1 - document 1332thread-2 - document 2332thread-4 - document 4339
# thread-0 - document 340
#
#
# thread-3 - document 3336
#  thread-2 - document 2333thread-4 - document 4340
# thread-0 - document 341thread-1 - document 1333
#
# thread-3 - document 3337
#
# thread-2 - document 2334thread-4 - document 4341
# thread-0 - document 342thread-1 - document 1334
#
# thread-3 - document 3338
#
# thread-2 - document 2335thread-4 - document 4342
# thread-0 - document 343
#
#
# thread-1 - document 1335thread-2 - document 2336thread-4 - document 4343thread-3 - document 3339thread-0 - document 344
#
#
#
#
# thread-1 - document 1336thread-2 - document 2337
#
# thread-4 - document 4344thread-3 - document 3340thread-0 - document 345thread-1 - document 1337thread-2 - document 2338
#
#
#
#
# thread-4 - document 4345 thread-0 - document 346thread-1 - document 1338thread-2 - document 2339
# thread-3 - document 3341
#
#
# thread-4 - document 4346
# thread-0 - document 347thread-1 - document 1339thread-2 - document 2340
#
#
#
# thread-4 - document 4347thread-3 - document 3342thread-0 - document 348thread-1 - document 1340thread-2 - document 2341
#
#
#
#
# thread-4 - document 4348thread-3 - document 3343  thread-2 - document 2342
#
# thread-0 - document 349thread-1 - document 1341
# thread-4 - document 4349thread-3 - document 3344
#
# thread-2 - document 2343
#
# thread-0 - document 350
# thread-4 - document 4350thread-3 - document 3345
# thread-1 - document 1342thread-2 - document 2344
#
# thread-0 - document 351
#
# thread-4 - document 4351thread-3 - document 3346
# thread-1 - document 1343thread-2 - document 2345
#
# thread-0 - document 352
#
# thread-4 - document 4352thread-3 - document 3347
# thread-1 - document 1344thread-2 - document 2346
#
# thread-0 - document 353
#
#  thread-3 - document 3348
# thread-1 - document 1345thread-2 - document 2347thread-4 - document 4353
# thread-0 - document 354
#
#
# thread-3 - document 3349
# thread-1 - document 1346thread-2 - document 2348thread-4 - document 4354
# thread-0 - document 355
#
#
# thread-3 - document 3350
# thread-1 - document 1347thread-2 - document 2349thread-4 - document 4355
# thread-0 - document 356
#
#
# thread-3 - document 3351
#  thread-2 - document 2350thread-4 - document 4356
#  thread-1 - document 1348
#
# thread-3 - document 3352thread-0 - document 357
# thread-2 - document 2351thread-4 - document 4357
#
# thread-1 - document 1349
#
# thread-3 - document 3353thread-0 - document 358
# thread-2 - document 2352thread-4 - document 4358
#
# thread-1 - document 1350
#
# thread-3 - document 3354thread-0 - document 359
# thread-2 - document 2353
#
# thread-1 - document 1351
# thread-4 - document 4359thread-3 - document 3355thread-0 - document 360
# thread-2 - document 2354
#
#
#
#  thread-3 - document 3356thread-0 - document 361thread-1 - document 1352thread-2 - document 2355thread-4 - document 4360
#
#
#
#
# thread-3 - document 3357thread-0 - document 362thread-1 - document 1353thread-2 - document 2356thread-4 - document 4361
#
#
#
#
# thread-3 - document 3358thread-0 - document 363thread-1 - document 1354thread-2 - document 2357thread-4 - document 4362
#
#
#
#
# thread-3 - document 3359thread-0 - document 364thread-1 - document 1355thread-2 - document 2358
#
#
#
# thread-4 - document 4363thread-3 - document 3360thread-0 - document 365 thread-2 - document 2359
#
#
# thread-1 - document 1356
# thread-4 - document 4364 thread-0 - document 366
# thread-2 - document 2360
# thread-3 - document 3361
# thread-1 - document 1357
# thread-4 - document 4365
# thread-0 - document 367
# thread-2 - document 2361
# thread-3 - document 3362
# thread-1 - document 1358
# thread-4 - document 4366
#
# thread-2 - document 2362
# thread-3 - document 3363thread-0 - document 368thread-1 - document 1359
# thread-4 - document 4367
#
#
# thread-2 - document 2363
# thread-3 - document 3364thread-0 - document 369thread-1 - document 1360
# thread-4 - document 4368
#
#
# thread-2 - document 2364
# thread-3 - document 3365thread-0 - document 370thread-1 - document 1361
# thread-4 - document 4369
#
#
# thread-2 - document 2365
#  thread-0 - document 371thread-1 - document 1362
# thread-4 - document 4370thread-3 - document 3366
#
# thread-2 - document 2366
#
# thread-0 - document 372thread-1 - document 1363
# thread-4 - document 4371thread-3 - document 3367
#
# thread-2 - document 2367
#
#
# thread-4 - document 4372 thread-0 - document 373thread-1 - document 1364thread-2 - document 2368
# thread-3 - document 3368
#
#
# thread-4 - document 4373
# thread-0 - document 374thread-1 - document 1365thread-2 - document 2369
# thread-3 - document 3369
#
#
# thread-4 - document 4374
# thread-0 - document 375thread-1 - document 1366thread-2 - document 2370
# thread-3 - document 3370
#
#
# thread-4 - document 4375
# thread-0 - document 376thread-1 - document 1367thread-2 - document 2371
# thread-3 - document 3371
#
#
# thread-4 - document 4376
# thread-0 - document 377thread-1 - document 1368
# thread-3 - document 3372
#
# thread-2 - document 2372
# thread-0 - document 378thread-1 - document 1369
# thread-4 - document 4377thread-3 - document 3373
#
#
#
# thread-0 - document 379thread-1 - document 1370thread-2 - document 2373thread-4 - document 4378thread-3 - document 3374
#
#
#
#
# thread-0 - document 380thread-1 - document 1371thread-2 - document 2374thread-4 - document 4379
#
#
#
# thread-3 - document 3375thread-0 - document 381thread-1 - document 1372thread-2 - document 2375thread-4 - document 4380
#
#
#
#
# thread-3 - document 3376 thread-1 - document 1373thread-2 - document 2376thread-4 - document 4381
# thread-0 - document 382
#
#
# thread-3 - document 3377
#  thread-2 - document 2377thread-4 - document 4382
# thread-0 - document 383thread-1 - document 1374
#
# thread-3 - document 3378
#
# thread-2 - document 2378thread-4 - document 4383
# thread-0 - document 384thread-1 - document 1375
#
# thread-3 - document 3379
#
# thread-2 - document 2379thread-4 - document 4384
# thread-0 - document 385thread-1 - document 1376
#
# thread-3 - document 3380
#
# thread-2 - document 2380thread-4 - document 4385
# thread-0 - document 386thread-1 - document 1377
#
# thread-3 - document 3381
#
# thread-2 - document 2381
# thread-0 - document 387thread-1 - document 1378
# thread-4 - document 4386thread-3 - document 3382
#
# thread-2 - document 2382
#
# thread-0 - document 388thread-1 - document 1379
# thread-4 - document 4387thread-3 - document 3383
#
# thread-2 - document 2383
#
# ...
# thread-1 - document 44841thread-0 - document 43833
# thread-2 - document 45838
#
# thread-3 - document 46840
# thread-1 - document 44842thread-0 - document 43834
# thread-2 - document 45839
#
# thread-3 - document 46841
# thread-1 - document 44843thread-0 - document 43835
#
#
# thread-3 - document 46842thread-2 - document 45840thread-1 - document 44844thread-0 - document 43836
#
#
#
# thread-3 - document 46843thread-2 - document 45841thread-1 - document 44845thread-0 - document 43837
#
#
#
# thread-3 - document 46844 thread-1 - document 44846thread-0 - document 43838
# thread-2 - document 45842
#
# thread-3 - document 46845
# thread-1 - document 44847thread-0 - document 43839
# thread-2 - document 45843
#
#
# thread-1 - document 44848thread-0 - document 43840thread-3 - document 46846thread-2 - document 45844
#
#
#
#  thread-0 - document 43841thread-3 - document 46847thread-2 - document 45845thread-1 - document 44849
#
#
#
# thread-0 - document 43842thread-3 - document 46848thread-2 - document 45846
#
#
# thread-1 - document 44850thread-0 - document 43843thread-3 - document 46849thread-2 - document 45847
#
#
#
# thread-1 - document 44851thread-0 - document 43844thread-3 - document 46850thread-2 - document 45848
#
#
#
# thread-1 - document 44852thread-0 - document 43845
#
# thread-3 - document 46851thread-2 - document 45849thread-1 - document 44853
#
#
# thread-0 - document 43846thread-3 - document 46852thread-2 - document 45850thread-1 - document 44854
#
#
#
# thread-0 - document 43847thread-3 - document 46853 thread-1 - document 44855
#
# thread-2 - document 45851
# thread-0 - document 43848thread-3 - document 46854
# thread-1 - document 44856
#
#
# thread-0 - document 43849thread-3 - document 46855thread-2 - document 45852thread-1 - document 44857
#
#
#
#  thread-3 - document 46856thread-2 - document 45853thread-1 - document 44858thread-0 - document 43850
#
#
#
# thread-3 - document 46857 thread-1 - document 44859thread-0 - document 43851
# thread-2 - document 45854
#
# thread-3 - document 46858
# thread-1 - document 44860
# thread-2 - document 45855
# thread-0 - document 43852thread-3 - document 46859
# thread-1 - document 44861
#
# thread-2 - document 45856
# thread-0 - document 43853thread-3 - document 46860
# thread-1 - document 44862
#
# thread-2 - document 45857
# thread-0 - document 43854thread-3 - document 46861
# thread-1 - document 44863
#
# thread-2 - document 45858
# thread-0 - document 43855thread-3 - document 46862
#
#
# thread-2 - document 45859thread-1 - document 44864thread-0 - document 43856
#
#
# thread-3 - document 46863 thread-1 - document 44865thread-0 - document 43857
# thread-2 - document 45860
#
#
# thread-1 - document 44866thread-0 - document 43858thread-3 - document 46864thread-2 - document 45861
#
#
#
# thread-1 - document 44867thread-0 - document 43859thread-3 - document 46865thread-2 - document 45862
#
#
#
# thread-1 - document 44868thread-0 - document 43860thread-3 - document 46866thread-2 - document 45863
#
#
#
# thread-1 - document 44869thread-0 - document 43861thread-3 - document 46867thread-2 - document 45864
#
#
#
# thread-1 - document 44870thread-0 - document 43862 thread-2 - document 45865
#
# thread-3 - document 46868
# thread-1 - document 44871thread-0 - document 43863
# thread-2 - document 45866
#
# thread-3 - document 46869
# thread-1 - document 44872thread-0 - document 43864
# thread-2 - document 45867
#
# thread-3 - document 46870
# thread-1 - document 44873
# thread-2 - document 45868
# thread-0 - document 43865thread-3 - document 46871
# thread-1 - document 44874
#
# thread-2 - document 45869
# thread-0 - document 43866thread-3 - document 46872
# thread-1 - document 44875
#
# thread-2 - document 45870
# thread-0 - document 43867thread-3 - document 46873
# thread-1 - document 44876
#
# thread-2 - document 45871
#  thread-3 - document 46874
# thread-1 - document 44877thread-0 - document 43868
# thread-2 - document 45872
#
# thread-3 - document 46875
# thread-1 - document 44878thread-0 - document 43869
# thread-2 - document 45873
#
# thread-3 - document 46876
# thread-1 - document 44879thread-0 - document 43870
# thread-2 - document 45874
#
# thread-3 - document 46877
# thread-1 - document 44880thread-0 - document 43871
# thread-2 - document 45875
#
# thread-3 - document 46878
# thread-1 - document 44881thread-0 - document 43872
# thread-2 - document 45876
#
# thread-3 - document 46879
# thread-1 - document 44882thread-0 - document 43873
# thread-2 - document 45877
#
#
# thread-1 - document 44883thread-0 - document 43874thread-3 - document 46880thread-2 - document 45878
#
#
#
#  thread-0 - document 43875thread-3 - document 46881thread-2 - document 45879thread-1 - document 44884
#
#
#
# thread-0 - document 43876thread-3 - document 46882thread-2 - document 45880thread-1 - document 44885
#
#
#
# thread-0 - document 43877thread-3 - document 46883thread-2 - document 45881thread-1 - document 44886
#
#
#
# thread-0 - document 43878thread-3 - document 46884 thread-1 - document 44887
#
# thread-2 - document 45882
# thread-0 - document 43879thread-3 - document 46885
#  Splitting content into words in 0.243000s
#
#
# thread-2 - document 45883thread-1 - document 44888
# thread-0 - document 43880thread-3 - document 46886
#
#
#
# thread-2 - document 45884thread-1 - document 44889thread-0 - document 43881thread-3 - document 46887
#
#
#
# thread-2 - document 45885 thread-0 - document 43882thread-3 - document 46888
# thread-1 - document 44890
#
# thread-2 - document 45886
# thread-0 - document 43883thread-3 - document 46889
# thread-1 - document 44891
#
# thread-2 - document 45887
#  thread-3 - document 46890
# thread-1 - document 44892thread-0 - document 43884
# thread-2 - document 45888
#
# thread-3 - document 46891
# thread-1 - document 44893thread-0 - document 43885
#
#
# thread-3 - document 46892thread-2 - document 45889 thread-0 - document 43886
#
# thread-1 - document 44894
# thread-3 - document 46893thread-2 - document 45890
# thread-0 - document 43887
#
# thread-1 - document 44895
# thread-3 - document 46894thread-2 - document 45891
# thread-0 - document 43888
#
# thread-1 - document 44896
# thread-3 - document 46895thread-2 - document 45892
# thread-0 - document 43889
#
# thread-1 - document 44897
# thread-3 - document 46896thread-2 - document 45893
# thread-0 - document 43890
#
# thread-1 - document 44898
# thread-3 - document 46897thread-2 - document 45894
# thread-0 - document 43891
#
# thread-1 - document 44899
# thread-3 - document 46898thread-2 - document 45895
# thread-0 - document 43892
#
# thread-1 - document 44900
# thread-3 - document 46899thread-2 - document 45896
# thread-0 - document 43893
#
# thread-1 - document 44901
# thread-3 - document 46900thread-2 - document 45897
#
#
# thread-1 - document 44902thread-0 - document 43894thread-3 - document 46901thread-2 - document 45898
#
#
#
#  thread-0 - document 43895thread-3 - document 46902thread-2 - document 45899thread-1 - document 44903
#
#
#
#  thread-3 - document 46903 thread-1 - document 44904thread-0 - document 43896
# thread-2 - document 45900
#
# thread-3 - document 46904
# thread-1 - document 44905thread-0 - document 43897
# thread-2 - document 45901
#
# thread-3 - document 46905
# thread-1 - document 44906thread-0 - document 43898
# thread-2 - document 45902
#
# thread-3 - document 46906
# thread-1 - document 44907thread-0 - document 43899
# thread-2 - document 45903
#
# thread-3 - document 46907
# thread-1 - document 44908thread-0 - document 43900
# thread-2 - document 45904
#
# thread-3 - document 46908
# thread-1 - document 44909
# thread-2 - document 45905
# thread-3 - document 46909
# thread-1 - document 44910thread-0 - document 43901
# thread-2 - document 45906
#
# thread-3 - document 46910
# thread-1 - document 44911thread-0 - document 43902
# thread-2 - document 45907
#
# thread-3 - document 46911
# thread-1 - document 44912thread-0 - document 43903
# thread-2 - document 45908
#
# thread-3 - document 46912
# thread-1 - document 44913thread-0 - document 43904
# thread-2 - document 45909
#
# thread-3 - document 46913
# thread-1 - document 44914thread-0 - document 43905
# thread-2 - document 45910
#
# thread-3 - document 46914
# thread-1 - document 44915thread-0 - document 43906
# thread-2 - document 45911
#
# thread-3 - document 46915
# thread-1 - document 44916thread-0 - document 43907
# thread-2 - document 45912
#
# thread-3 - document 46916
# thread-1 - document 44917thread-0 - document 43908
# thread-2 - document 45913
#
# thread-3 - document 46917
# thread-1 - document 44918thread-0 - document 43909
# thread-2 - document 45914
#
# thread-3 - document 46918
#  thread-0 - document 43910
# thread-2 - document 45915thread-1 - document 44919
#
#
# thread-0 - document 43911thread-3 - document 46919thread-2 - document 45916thread-1 - document 44920
#
#
#
#  thread-3 - document 46920thread-2 - document 45917thread-1 - document 44921thread-0 - document 43912
#
#
#
# thread-3 - document 46921thread-2 - document 45918thread-1 - document 44922thread-0 - document 43913
#
#
#
# thread-3 - document 46922thread-2 - document 45919thread-1 - document 44923thread-0 - document 43914
#
#
#
# thread-3 - document 46923thread-2 - document 45920thread-1 - document 44924thread-0 - document 43915
#
#
#
# thread-3 - document 46924thread-2 - document 45921thread-1 - document 44925
#
#
# thread-0 - document 43916thread-3 - document 46925thread-2 - document 45922thread-1 - document 44926
#
#
#
# thread-0 - document 43917thread-3 - document 46926 thread-1 - document 44927
#
# thread-2 - document 45923
# thread-0 - document 43918thread-3 - document 46927
#
#
# thread-2 - document 45924thread-1 - document 44928thread-0 - document 43919thread-3 - document 46928
#
#
#
# thread-2 - document 45925 thread-0 - document 43920thread-3 - document 46929
# thread-1 - document 44929
#
# thread-2 - document 45926
# thread-0 - document 43921thread-3 - document 46930
# thread-1 - document 44930
#
# thread-2 - document 45927
# thread-0 - document 43922thread-3 - document 46931
# thread-1 - document 44931
#
# thread-2 - document 45928
# thread-0 - document 43923thread-3 - document 46932
#
#
#  thread-1 - document 44932thread-0 - document 43924thread-3 - document 46933thread-2 - document 45929
#
#
#
# thread-1 - document 44933thread-0 - document 43925thread-3 - document 46934
#
#
# thread-2 - document 45930thread-1 - document 44934thread-0 - document 43926
#
#
# thread-3 - document 46935thread-2 - document 45931 thread-0 - document 43927
#
# thread-1 - document 44935
# thread-3 - document 46936thread-2 - document 45932
# thread-0 - document 43928
#
# thread-1 - document 44936
# thread-3 - document 46937thread-2 - document 45933
# thread-0 - document 43929
#
#
# thread-3 - document 46938 thread-1 - document 44937thread-0 - document 43930
# thread-2 - document 45934
#
# thread-3 - document 46939
# thread-1 - document 44938thread-0 - document 43931
# thread-2 - document 45935
#
# thread-3 - document 46940
# thread-1 - document 44939thread-0 - document 43932
# thread-2 - document 45936
#
# thread-3 - document 46941
# thread-1 - document 44940
# thread-2 - document 45937
# thread-0 - document 43933
#
# thread-3 - document 46942thread-2 - document 45938thread-1 - document 44941
#
#
# thread-0 - document 43934thread-3 - document 46943thread-2 - document 45939thread-1 - document 44942
#
#
#
# thread-0 - document 43935thread-3 - document 46944thread-2 - document 45940thread-1 - document 44943
#
#
#
# thread-0 - document 43936thread-3 - document 46945thread-2 - document 45941thread-1 - document 44944
#
#
#
#  thread-3 - document 46946thread-2 - document 45942thread-1 - document 44945thread-0 - document 43937
#
#
#
#  thread-2 - document 45943thread-1 - document 44946thread-0 - document 43938thread-3 - document 46947
#
#
#
# thread-2 - document 45944thread-1 - document 44947 thread-3 - document 46948
#
# thread-0 - document 43939
# thread-2 - document 45945
# thread-3 - document 46949
# thread-1 - document 44948thread-0 - document 43940
# thread-2 - document 45946
#
# thread-3 - document 46950
# thread-1 - document 44949thread-0 - document 43941
# thread-2 - document 45947
#
# thread-3 - document 46951
# thread-1 - document 44950thread-0 - document 43942
# thread-2 - document 45948
#
# thread-3 - document 46952
# thread-1 - document 44951thread-0 - document 43943
# thread-2 - document 45949
#
# thread-3 - document 46953
# thread-1 - document 44952thread-0 - document 43944
# thread-2 - document 45950
#
# thread-3 - document 46954
# thread-1 - document 44953thread-0 - document 43945
# thread-2 - document 45951
#
# thread-3 - document 46955
# thread-1 - document 44954thread-0 - document 43946
# thread-2 - document 45952
#
# thread-3 - document 46956
# thread-1 - document 44955thread-0 - document 43947
# thread-2 - document 45953
#
# thread-3 - document 46957
# thread-1 - document 44956thread-0 - document 43948
# thread-2 - document 45954
#
# thread-3 - document 46958
# thread-1 - document 44957
#
# thread-0 - document 43949thread-3 - document 46959thread-2 - document 45955thread-1 - document 44958
#
#
#
#  thread-3 - document 46960thread-2 - document 45956 thread-0 - document 43950
#
# thread-1 - document 44959
# thread-3 - document 46961thread-2 - document 45957
# thread-0 - document 43951
#
#
# thread-3 - document 46962thread-2 - document 45958thread-1 - document 44960thread-0 - document 43952
#
#
#
# thread-3 - document 46963thread-2 - document 45959thread-1 - document 44961thread-0 - document 43953
#
#
#
# thread-3 - document 46964thread-2 - document 45960thread-1 - document 44962thread-0 - document 43954
#
#
#
# thread-3 - document 46965thread-2 - document 45961thread-1 - document 44963thread-0 - document 43955
#
#
#
# thread-3 - document 46966thread-2 - document 45962thread-1 - document 44964thread-0 - document 43956
#
#
#
# thread-3 - document 46967thread-2 - document 45963thread-1 - document 44965thread-0 - document 43957
#
#
#
# thread-3 - document 46968thread-2 - document 45964thread-1 - document 44966thread-0 - document 43958
#
#
#
# thread-3 - document 46969thread-2 - document 45965thread-1 - document 44967thread-0 - document 43959
#
#
#
# thread-3 - document 46970thread-2 - document 45966thread-1 - document 44968thread-0 - document 43960
#
#
#
# thread-3 - document 46971thread-2 - document 45967thread-1 - document 44969thread-0 - document 43961
#
#
#
# thread-3 - document 46972thread-2 - document 45968thread-1 - document 44970thread-0 - document 43962
#
#
#
# thread-3 - document 46973thread-2 - document 45969thread-1 - document 44971thread-0 - document 43963
#
#
#
#  thread-2 - document 45970thread-1 - document 44972thread-0 - document 43964thread-3 - document 46974
#
#
#
#  thread-1 - document 44973thread-0 - document 43965thread-3 - document 46975thread-2 - document 45971
#
#
#
# thread-1 - document 44974thread-0 - document 43966thread-3 - document 46976thread-2 - document 45972
#
#
#
# thread-1 - document 44975thread-0 - document 43967thread-3 - document 46977thread-2 - document 45973
#
#
#
# thread-1 - document 44976thread-0 - document 43968thread-3 - document 46978thread-2 - document 45974
#
#
#
# thread-1 - document 44977thread-0 - document 43969 thread-2 - document 45975
#
# thread-3 - document 46979
# thread-1 - document 44978thread-0 - document 43970
# thread-2 - document 45976
#
# thread-3 - document 46980
# thread-1 - document 44979thread-0 - document 43971
#
#
# thread-3 - document 46981thread-2 - document 45977thread-1 - document 44980thread-0 - document 43972
#
#
#
# thread-3 - document 46982thread-2 - document 45978thread-1 - document 44981thread-0 - document 43973
#
#
#
# thread-3 - document 46983thread-2 - document 45979thread-1 - document 44982thread-0 - document 43974
#
#
#
# thread-3 - document 46984thread-2 - document 45980thread-1 - document 44983thread-0 - document 43975
#
#
#
# thread-3 - document 46985thread-2 - document 45981thread-1 - document 44984thread-0 - document 43976
#
#
#
# thread-3 - document 46986thread-2 - document 45982thread-1 - document 44985
#
#
# thread-0 - document 43977thread-3 - document 46987thread-2 - document 45983thread-1 - document 44986
#
#
#
#  Total time for thread-3: 16.497000s
# thread-2 - document 45984 thread-0 - document 43978
#
# thread-1 - document 44987
#
# thread-2 - document 45985thread-0 - document 43979Total time for thread-1: 16.485000s
#
#
#
# thread-2 - document 45986thread-0 - document 43980
#
# thread-2 - document 45987thread-0 - document 43981
#
# Total time for thread-2: 16.448000s
# thread-0 - document 43982
#
# thread-0 - document 43983
# thread-0 - document 43984
# thread-0 - document 43985
# thread-0 - document 43986
# thread-0 - document 43987
# Total time for thread-0: 16.506000s
#
# Done replace_content_by_index in 348.203000s
#
# TOTAL TIME FOR TOPIC 'kinh-doanh': 365.078000s
